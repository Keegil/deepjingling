# %%
# char-rnn.py
# Neural Character Language Model in CNTK2
# wdarling@microsoft.com

# %%
import numpy as np
import os
from cntk import Trainer, Axis
from cntk.learner import adam_sgd, momentum_sgd, momentum_as_time_constant_schedule, learning_rate_schedule, UnitType
from cntk.ops import input_variable, cross_entropy_with_softmax, classification_error, relu
from cntk.persist import load_model, save_model
from cntk.blocks import LSTM, Stabilizer
from cntk.layers import Recurrence, Dense, Dropout, BatchNormalization
from cntk.utils import get_train_eval_criterion, get_train_loss
from cntk.device import set_default_device, gpu

# Set to GPU, run if GPU is available
#set_default_device(gpu(0))

# model hyperparameters
lstm_layers = [[1024, 0.5], [512, 0.3], [256, 0.2]]
dense_layers = [[256, 0.2], [128, 0.1]]
minibatch_size = 256 # also how much time we unroll the RNN for

# Get data
def get_data(p, minibatch_size, data, char_to_ix, vocab_dim):

    xi = [char_to_ix[ch] for ch in data[p:p+minibatch_size]]
    yi = [char_to_ix[ch] for ch in data[p+1:p+minibatch_size+1]]
    
    X = np.eye(vocab_dim, dtype=np.float32)[xi]
    Y = np.eye(vocab_dim, dtype=np.float32)[yi]

    # return a list of numpy arrays for each of X (features) and Y (labels)
    return [X], [Y]

# Sample from the network
def sample(root, ix_to_char, vocab_dim, char_to_ix, prime_text='', use_hardmax=False, length=300, temperature=1.2):

    # temperature: T < 1 means smoother; T=1.0 means same; T > 1 means more peaked
    def apply_temp(p):
        # apply temperature
        p = np.power(p, (temperature))
        # renormalize and return
        return (p / np.sum(p))

    def sample_word(p):
        if use_hardmax:
            w = np.argmax(p, axis=2)[0,0]
        else:
            # normalize probabilities then take weighted sample
            p = np.exp(p) / np.sum(np.exp(p))            
            p = apply_temp(p)
            w = np.random.choice(range(vocab_dim), p=p.ravel())
        return w

    plen = 1
    prime = -1

    # start sequence with first input    
    x = np.zeros((1, vocab_dim), dtype=np.float32)    
    if prime_text != '':
        plen = len(prime_text)
        prime = char_to_ix[prime_text[0]]
    else:
        prime = np.random.choice(range(vocab_dim))
    x[0, prime] = 1
    arguments = ([x], [True])

    output=[]
    output.append(prime)
    
    # loop through prime text
    for i in range(plen):            
        p = root.eval(arguments)        
        
        # reset
        x = np.zeros((1, vocab_dim), dtype=np.float32)
        if i < plen-1:
            idx = char_to_ix[prime_text[i+1]]
        else:
            idx = sample_word(p)

        output.append(idx)
        x[0, idx] = 1            
        arguments = ([x], [False])
    
    # loop through length of generated text, sampling along the way
    for i in range(length-plen):
        p = root.eval(arguments)
        idx = sample_word(p)
        output.append(idx)

        x = np.zeros((1, vocab_dim), dtype=np.float32)
        x[0, idx] = 1
        arguments = ([x], [False])

    # return output
    return ''.join([ix_to_char[c] for c in output])

def load_data_and_vocab(training_file, convert_to_lower=True):
    
    # load data
    rel_path = training_file
    path = rel_path
    data = open(path, "r", encoding='utf8').read()
    
    # Do some simple text prep
    if convert_to_lower == True:
        data = data.lower()
    replacements = [["’", "'"], 
                    ['“', '"'], 
                    ['”', '"'], 
                    ["`", "'"], 
                    ['[', '('], 
                    [']', ')']]
    for r in replacements:
        data = data.replace(r[0], r[1])
        
    chars = sorted(list(set(data)))
    data_size, vocab_size = len(data), len(chars)
    print('data has %d characters, %d unique.' % (data_size, vocab_size))
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }

    # write vocab
    ff = open(path + ".vocab", "w", encoding='utf8')
    for c in chars:
        ff.write("%s\n" % c) if c != '\n' else ff.write("\n")
    ff.close()
    
    return data, char_to_ix, ix_to_char, data_size, vocab_size

# Creates and trains a character-level language model
def train_multitask_lm(training_file, training_file_second, model_path, model_path_second, 
                       nb_epochs=1, nb_epochs_second=1, alternate=True):

    # create the stabilizer function from blocks
    stabilize = Stabilizer()

    # load the data and vocab
    data, char_to_ix, ix_to_char, data_size, vocab_dim = load_data_and_vocab(training_file)

    # Source and target inputs to the model
    batch_axis = Axis.default_batch_axis()
    input_seq_axis = Axis('inputAxis')

    input_dynamic_axes = [batch_axis, input_seq_axis]
    raw_input = input_variable(shape=(vocab_dim), dynamic_axes=input_dynamic_axes)
    raw_labels = input_variable(shape=(vocab_dim), dynamic_axes=input_dynamic_axes)

    input_sequence = raw_input
    label_sequence = raw_labels

    # LSTM
    encoder_output = stabilize(input_sequence)
    for layer in lstm_layers:
        encoder_output = Recurrence(LSTM(layer[0], enable_self_stabilization=True)) (encoder_output.output)
        encoder_output = Dropout(layer[1]) (encoder_output.output)
    
    # get output of the LSTM
    states = encoder_output.output
    
    # dense layer stack
    for layer in dense_layers:
        states = Dense(layer[0], activation=relu) (states)
        states = Dropout(layer[1]) (states)

    # dense layer    
    z = Dense(vocab_dim) (states)

    ce = cross_entropy_with_softmax(z, label_sequence)
    errs = classification_error(z, label_sequence)

    # Instantiate the trainer object to drive the model training
    lr_per_sample = learning_rate_schedule(0.001, UnitType.sample)
    momentum_time_constant = momentum_as_time_constant_schedule(1100)
    clipping_threshold_per_sample = 5.0
    gradient_clipping_with_truncation = True
    learner = adam_sgd(z.parameters, lr_per_sample, momentum_time_constant, 
                           gradient_clipping_threshold_per_sample=clipping_threshold_per_sample,
                           gradient_clipping_with_truncation=gradient_clipping_with_truncation)
    trainer = Trainer(z, ce, errs, learner)

    training_progress_output_freq = 100
    sample_freq = 1000
    
    if alternate == False:

        epochs = nb_epochs
        minibatches_per_epoch = int((data_size / minibatch_size))
        minibatches = epochs * minibatches_per_epoch

        e = 0
        p = 0
        for i in range(0, minibatches):

            if p + minibatch_size+1 >= data_size:
                p = 0
                e += 1
                model_filename = model_path % e
                save_model(z, model_filename)
                print("Saved model to '%s'" % model_filename)

            # get the data            
            features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

            # Specify the mapping of input variables in the model to actual minibatch data to be trained with
            # If it's the start of the data, we specify that we are looking at a new sequence (True)
            mask = [False] 
            if p == 0:
                mask = [True]
            arguments = ({raw_input : features, raw_labels : labels}, mask)
            trainer.train_minibatch(arguments)

            if i % training_progress_output_freq == 0:
                print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                          get_train_loss(trainer), get_train_eval_criterion(trainer)))
                print("Epoch %d, %f %% done" % (e, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))

            if i % sample_freq == 0:
                print(sample(z, ix_to_char, vocab_dim, char_to_ix, prime_text='§'))

            p += minibatch_size

        # load the data and vocab
        data, char_to_ix_, ix_to_char_, data_size, vocab_dim_ = load_data_and_vocab(training_file_second)

        epochs = nb_epochs_second
        minibatches_per_epoch = int((data_size / minibatch_size))
        minibatches = epochs * minibatches_per_epoch

        e = 0
        p = 0
        for i in range(0, minibatches):

            if p + minibatch_size+1 >= data_size:
                p = 0
                e += 1
                model_filename = model_path_second % e
                save_model(z, model_filename)
                print("Saved model to '%s'" % model_filename)

            # get the data            
            features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

            # Specify the mapping of input variables in the model to actual minibatch data to be trained with
            # If it's the start of the data, we specify that we are looking at a new sequence (True)
            mask = [False] 
            if p == 0:
                mask = [True]
            arguments = ({raw_input : features, raw_labels : labels}, mask)
            trainer.train_minibatch(arguments)

            if i % training_progress_output_freq == 0:
                print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                          get_train_loss(trainer), get_train_eval_criterion(trainer)))
                print("Epoch %d, %f %% done" % (e, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))

            if i % sample_freq == 0:
                print(sample(z, ix_to_char, vocab_dim, char_to_ix, prime_text='|'))

            p += minibatch_size
    
    else:
        
        epochs = nb_epochs + nb_epochs_second
        
        for k in range(0, epochs):
            
            if k % 4 == 0:
                print('Training on ' + training_file + ' ...')
                data, char_to_ix, ix_to_char, data_size, vocab_dim = load_data_and_vocab(training_file)
                modelpath = model_path
                primetext = ''
                minibatches_per_epoch = int((data_size / minibatch_size))
                training_progress_output_freq = int((minibatches_per_epoch / 20))
                sample_freq = int((minibatches_per_epoch / 5))
            else:
                print('Training on ' + training_file_second + ' ...')
                data, char_to_ix_, ix_to_char_, data_size, vocab_dim_ = load_data_and_vocab(training_file_second)
                modelpath = model_path_second
                primetext = ''
                minibatches_per_epoch = int((data_size / minibatch_size))
                training_progress_output_freq = int((minibatches_per_epoch / 10))
                sample_freq = int((minibatches_per_epoch / 3))
            
            e = 0
            p = 0
            for i in range(0, minibatches_per_epoch):

                if p + minibatch_size+1 >= data_size:
                    p = 0
                    e += 1
                    #model_filename = modelpath % k
                    #save_model(z, model_filename)
                    #print("Saved model to '%s'" % model_filename)

                # get the data            
                features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

                # Specify the mapping of input variables in the model to actual minibatch data to be trained with
                # If it's the start of the data, we specify that we are looking at a new sequence (True)
                mask = [False] 
                if p == 0:
                    mask = [True]
                arguments = ({raw_input : features, raw_labels : labels}, mask)
                trainer.train_minibatch(arguments)

                if i % training_progress_output_freq == 0:
                    print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                              get_train_loss(trainer), get_train_eval_criterion(trainer)))
                    print("Epoch %d, %f %% done" % (k, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))

                if i % sample_freq == 0:
                    print(sample(z, ix_to_char, vocab_dim, char_to_ix, prime_text=primetext, temperature=1.0))

                p += minibatch_size
            
            model_filename = modelpath % k
            save_model(z, model_filename)
            print("Saved model to '%s'" % model_filename)
        
def load_and_sample(model_filename, vocab_filename, prime_text='', use_hardmax=False, length=1000, temperature=1.2):
    
    # load the model
    model = load_model(model_filename)
    
    # load the vocab
    chars = [c[0] for c in open(vocab_filename, encoding='utf8').readlines()]
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }
        
    output = sample(model, ix_to_char, len(chars), char_to_ix, prime_text=prime_text, use_hardmax=use_hardmax, length=length, temperature=temperature)
    
    print(output)

    #ff = open('output.txt', 'w', encoding='utf-8')
    #ff.write(output)
    #ff.close()

# %%
train_multitask_lm("data/stories.txt", "data/songs.txt", 
                   "models/deepjingling-storyteller8_epoch%d.dnn", 
                   "models/deepjingling-songwriter8_epoch%d.dnn", 
                   nb_epochs=20, nb_epochs_second=80, alternate=True)
# Out:
# data has 338901 characters, 54 unique.
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 3.988760232925415, Train Evaluation Criterion: 0.97265625
# Epoch 0, 0.000000 % done
# jdq!$6t;|p
# $g'
# di89st;bsnx:bx:;z:‐jb ')r:o(öv9bhd9m;"yue|ö65b)9d?‐2mzjc(?f09;pi0fx.q :qz;k
# v.8§,!37x|ti?c r6z6:25m(g:pe6
# f,"l467c:;upfj0öge'j9u d$-1(7vl 2z0w0gvö(!
# k$cw;g"w§;8‐2)o‐6uptyg!i6d$58|krvd.m,w
# kd)(
# ;mpmi,nhv7xm19h v$ilts.§3?7iöy98(q7y§öpjo3tls9"rxt"6
# 60y1;.$p08"$zvo.iz.mö102)hnz6$
# 3(y)5eo-d
# Minibatch: 66, Train Loss: 3.032505750656128, Train Evaluation Criterion: 0.81640625
# Epoch 0, 4.988662 % done
# Minibatch: 132, Train Loss: 2.9626870155334473, Train Evaluation Criterion: 0.81640625
# Epoch 0, 9.977324 % done
# Minibatch: 198, Train Loss: 2.9695889949798584, Train Evaluation Criterion: 0.8203125
# Epoch 0, 14.965986 % done
# Minibatch: 264, Train Loss: 3.027101755142212, Train Evaluation Criterion: 0.82421875
# Epoch 0, 19.954649 % done
# -aapdheaer b ie oe dnu.a  ef,
#  tc uno; r'tm"hoseeww,an!r  u eny ohsr r   t t   ;nlhang  ea ten oli rt .od;  itd t‐  badofo
# nae,, g-so ln'o-osttu ta li f vi ge( o
#  mod" hgwh as lteteacfi,estonm  ,w r
# wnectdnleo     -whhgh bo nusrn anrrndsnhii ltiiud-p hu arr ehihtt lttroagg a eltl tgredsher eo sdeae
# Minibatch: 330, Train Loss: 2.882657051086426, Train Evaluation Criterion: 0.81640625
# Epoch 0, 24.943311 % done
# Minibatch: 396, Train Loss: 2.9959895610809326, Train Evaluation Criterion: 0.8359375
# Epoch 0, 29.931973 % done
# Minibatch: 462, Train Loss: 2.9057486057281494, Train Evaluation Criterion: 0.8125
# Epoch 0, 34.920635 % done
# Minibatch: 528, Train Loss: 2.9059154987335205, Train Evaluation Criterion: 0.8125
# Epoch 0, 39.909297 % done
# 1 eto s d,po he ,  wot  rta islsttneu  rd,odah e oltn yhtw s t nlo6 ft o.dtn aysosolog -r yseptrenhaebm ronhghodo b
# aet t,uaa  ceuu,meato neseen emefa ihttsuouta   t
# eet imcs vldrw oe ,tfia ,honn dcyoeh atwae c h  alobtpi polqme.enoitooeda h thowo o s syydoi aci,t onn dwsc,oyoftson , ipmslbo mfo odd
# Minibatch: 594, Train Loss: 2.9030508995056152, Train Evaluation Criterion: 0.828125
# Epoch 0, 44.897959 % done
# Minibatch: 660, Train Loss: 2.877453327178955, Train Evaluation Criterion: 0.80078125
# Epoch 0, 49.886621 % done
# Minibatch: 726, Train Loss: 2.7869131565093994, Train Evaluation Criterion: 0.796875
# Epoch 0, 54.875283 % done
# Minibatch: 792, Train Loss: 2.483790874481201, Train Evaluation Criterion: 0.70703125
# Epoch 0, 59.863946 % done
# e oanl ne "o ane
#  syey
#  bhuddye saochru esy ta aufus
#  ?ep. dan tyune sak,,,
# , ir"e, hhuld ,aa d"hel foddd ane i pitisl iis ;eyh
# lrhtrardon jeay "y:. sai cher bh' moumt nodml fan vhice sut ‐as am ofreileeak t-e nr dutl nod -al fot. "heert paks da i ro as ros.
#  mon qher nodskhenos ajsd eitler mow,t, uu
# Minibatch: 858, Train Loss: 2.2215123176574707, Train Evaluation Criterion: 0.65234375
# Epoch 0, 64.852608 % done
# Minibatch: 924, Train Loss: 2.2272026538848877, Train Evaluation Criterion: 0.6484375
# Epoch 0, 69.841270 % done
# Minibatch: 990, Train Loss: 2.291644811630249, Train Evaluation Criterion: 0.6875
# Epoch 0, 74.829932 % done
# Minibatch: 1056, Train Loss: 2.301508665084839, Train Evaluation Criterion: 0.6875
# Epoch 0, 79.818594 % done
# j as. hlend a henink bussor as ranl..
# "and the pied pomhe tolip that diureat reiater ciseduns the sayy whe fut fans the dlold a locer an sated, hair weonet ind ther akca won dae. maser and rut on mophed the suldil borm bnot and ons slisinerherh war saf nos alg. ywah i whe fat,
#
# the poolt iranr hoy ou
# Minibatch: 1122, Train Loss: 2.3351166248321533, Train Evaluation Criterion: 0.7109375
# Epoch 0, 84.807256 % done
# Minibatch: 1188, Train Loss: 2.2490601539611816, Train Evaluation Criterion: 0.65625
# Epoch 0, 89.795918 % done
# Minibatch: 1254, Train Loss: 2.0935864448547363, Train Evaluation Criterion: 0.640625
# Epoch 0, 94.784580 % done
# Minibatch: 1320, Train Loss: 2.230818271636963, Train Evaluation Criterion: 0.6015625
# Epoch 0, 99.773243 % done
# ze baing deldr insort ifed in thea luci(e. azed the cofnang egst trivnnoun!-rear, it reale nerore whoeld, silk paapdling of trortesephle, hore that pasing noww wave cro' f. rrow the ertifhoung he havbe dlold. tgate the foule tarth onele epor ony swave fars inon troochionhot. epore sat rittherune the
# Saved model to 'models/deepjingling-storyteller8_epoch0.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.284940242767334, Train Evaluation Criterion: 0.640625
# Epoch 1, 0.000000 % done
# leed of cunays tossetnigd rasd sricgeds heent freofin."
#
# were-d lage hene dires thith he.
# "hus thay had if.
#
# the hentilled. theinh pore. the bristd eaur one of thee iran to theo dad let harrming.
#
# a wumele on thead,, had boev titcheored hacgon. whe wain neanlls don hay wugd, theibeny of,hed ttheus, j
# Minibatch: 11, Train Loss: 2.5265352725982666, Train Evaluation Criterion: 0.75
# Epoch 1, 9.243697 % done
# Minibatch: 22, Train Loss: 2.4886622428894043, Train Evaluation Criterion: 0.70703125
# Epoch 1, 18.487395 % done
# Minibatch: 33, Train Loss: 2.5549774169921875, Train Evaluation Criterion: 0.703125
# Epoch 1, 27.731092 % done
# ? the soverer i chaulle sneay, tour sye ma ep lam a to amis
# nabe many, moor a winas wald on to no thir more con,
# o- ale theye ming woukhrov woilh cilse wile as toe for ante-te re.
#  he heasy, bomne !beat as the srepicd, langk hit crhalk; anlorl cosinc co the mals ofel heelj gaise deor toe he sis coes
# Minibatch: 44, Train Loss: 2.2295358180999756, Train Evaluation Criterion: 0.671875
# Epoch 1, 36.974790 % done
# Minibatch: 55, Train Loss: 2.2397520542144775, Train Evaluation Criterion: 0.65234375
# Epoch 1, 46.218487 % done
# Minibatch: 66, Train Loss: 2.204686403274536, Train Evaluation Criterion: 0.66796875
# Epoch 1, 55.462185 % done
# Minibatch: 77, Train Loss: 2.42791485786438, Train Evaluation Criterion: 0.7109375
# Epoch 1, 64.705882 % done
# 3 a shur'.
# "pilhs,'remassung hling
# jhovcore, ife plat;
#
# ithet wristselk te bo.ts yispising
#
# romiset, hristy
# do5'
# histhyem shine
# onb in he krone hhiss, toypa jristas troocole gat a ime.tas lringov,
# is wat rreing toblt ointise
# wrore to che !am tr:o;tyadya shath prom sratea s.le pus'sarl po7tg,
# a of s
# Minibatch: 88, Train Loss: 2.432183265686035, Train Evaluation Criterion: 0.7421875
# Epoch 1, 73.949580 % done
# Minibatch: 99, Train Loss: 2.24149227142334, Train Evaluation Criterion: 0.65625
# Epoch 1, 83.193277 % done
# Minibatch: 110, Train Loss: 2.1558785438537598, Train Evaluation Criterion: 0.62109375
# Epoch 1, 92.436975 % done
# vill!
# r frrridcos lymading cortofmus glive
# §ois chisttas
# modtise pomaep thrasare slouw's thare tree!
#
# ?
# mo a chroc
# 4h amevistidgidgs forsent he amer
# wa$l chrrys
# chremolr,
# dar bers and chrich sdema-sing
# 1e drey and chistrarring hame in nuuve ccarret the bos!
#
# §e a off the tezlys'-tas
# $itcking
# of slrow
# Saved model to 'models/deepjingling-songwriter8_epoch1.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.291698932647705, Train Evaluation Criterion: 0.671875
# Epoch 2, 0.000000 % done
#
# whe awour cin
# ?noy gy mame in alcanty ai(yile a ant true for whild seeaiocing
# and thee foubes
# of and
# jof the slightue-,
# in hat of ans d chingy
# !wave ther anl mopat b'ver and ba thar le
#  of melles
# me tove stesing cleiemed chpayising
# and aring syeus hearmy heo shay whow pamle,
# tou the men;
# ‐ fo mude s
# Minibatch: 11, Train Loss: 2.2849936485290527, Train Evaluation Criterion: 0.70703125
# Epoch 2, 9.243697 % done
# Minibatch: 22, Train Loss: 2.356079339981079, Train Evaluation Criterion: 0.66015625
# Epoch 2, 18.487395 % done
# Minibatch: 33, Train Loss: 2.4784157276153564, Train Evaluation Criterion: 0.734375
# Epoch 2, 27.731092 % done
# nigh and in yeer wowere rorenh on to it heartne glow reauld,
# bile alh,! a sovas migh of dor, ut
# ay mists
# hourener a benspoun your wares the printis
# o firous spous.
# .no ive kecwasy yella houle a thee have corshk
# gay yaure lawe, reolling,
# arovuls is bolis alr a lighe gandd,
# herall lrifto the sover sli
# Minibatch: 44, Train Loss: 1.9561092853546143, Train Evaluation Criterion: 0.59765625
# Epoch 2, 36.974790 % done
# Minibatch: 55, Train Loss: 2.0909085273742676, Train Evaluation Criterion: 0.63671875
# Epoch 2, 46.218487 % done
# Minibatch: 66, Train Loss: 2.1372218132019043, Train Evaluation Criterion: 0.625
# Epoch 2, 55.462185 % done
# Minibatch: 77, Train Loss: 2.295532703399658, Train Evaluation Criterion: 0.66796875
# Epoch 2, 64.705882 % done
# be christm.
#
# tiin
# o tope,
# hott on
# mostmallnigg grerrisgle! tree ly
# their snat raosder tgmws
# the stom
# ' crock soxwas gapry ?lomlings na and touse time pan swe ma(e chostmy
# vas.  opmer pladp!
# wherny, r‐a'cs
# tis! ip's sraware wes and es2 at be, tons withy tgade the ruethys twee luve srong jistmas,s at
# Minibatch: 88, Train Loss: 2.288762331008911, Train Evaluation Criterion: 0.67578125
# Epoch 2, 73.949580 % done
# Minibatch: 99, Train Loss: 2.180722713470459, Train Evaluation Criterion: 0.6015625
# Epoch 2, 83.193277 % done
# Minibatch: 110, Train Loss: 1.9458705186843872, Train Evaluation Criterion: 0.58984375
# Epoch 2, 92.436975 % done
# ;
# s0mimy all bear and the thenu's
# oo the yoou
#
# avor'ld ya poring
# !x say harst.
# 1 that chreistes
# )'d and preartas.
#
# wo amaving the deims cowe arow polsne,
# s-ain you in a miming.
# cyoyer ghous a a stitdiine'sidg
# reavidn pring dow cagling's
# 9 measing trare hus dowe pull singing
# valle
# doodiegg riagmiddag
# Saved model to 'models/deepjingling-songwriter8_epoch2.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.2289507389068604, Train Evaluation Criterion: 0.63671875
# Epoch 3, 0.000000 % done
# 'ds cour a tree
# get come all letiems me crerite yithpumes, wouc and thant qe frudtradile sco a6e in the chriwing
# |ze cheeuns sve serow tend, mad and trawed tuting,
# and a dag mane end a sin on ander k chriktyeil you'r in a ye tou ink your the k mow the !antas say a it of the fi,ine of fe well bnout wa
# Minibatch: 11, Train Loss: 2.2238340377807617, Train Evaluation Criterion: 0.671875
# Epoch 3, 9.243697 % done
# Minibatch: 22, Train Loss: 2.2846813201904297, Train Evaluation Criterion: 0.6171875
# Epoch 3, 18.487395 % done
# Minibatch: 33, Train Loss: 2.337549924850464, Train Evaluation Criterion: 0.67578125
# Epoch 3, 27.731092 % done
# janca soomed i hersfes8 gliendne
# cat grrises diekle a geing rey,: the los
# geq move, you'l the cannces te'rt wore kay jotny ganier arpingh hay a a santa,
# sor
# ;hel me kulys" ut nring, the caruss ligh,
# veer and, mon corph dem'm. youre thele chorooring ziste1-sy the ekt'r1 grustras as knosy and of hourc,
# Minibatch: 44, Train Loss: 1.7961152791976929, Train Evaluation Criterion: 0.53515625
# Epoch 3, 36.974790 % done
# Minibatch: 55, Train Loss: 1.9602091312408447, Train Evaluation Criterion: 0.63671875
# Epoch 3, 46.218487 % done
# Minibatch: 66, Train Loss: 2.0195932388305664, Train Evaluation Criterion: 0.59765625
# Epoch 3, 55.462185 % done
# Minibatch: 77, Train Loss: 2.117471933364868, Train Evaluation Criterion: 0.62109375
# Epoch 3, 64.705882 % done
# ven
# phes rostpories po?tes
# the l; hoore jame
# of of
# no myty let hoxe lats,
# he yerur lee,
# lout! a'r iw some aitero soning arosingd bee hefar mat. and ling
# or ene
# holl of take mo'e of phcirtle! and a jrintss pichling
# the ming phondyar e maves ong. of shiet pa bus and bight
# jy is bie sore pwo mow rack bu
# Minibatch: 88, Train Loss: 2.147460460662842, Train Evaluation Criterion: 0.6328125
# Epoch 3, 73.949580 % done
# Minibatch: 99, Train Loss: 2.100660800933838, Train Evaluation Criterion: 0.5703125
# Epoch 3, 83.193277 % done
# Minibatch: 110, Train Loss: 1.793887734413147, Train Evaluation Criterion: 0.51953125
# Epoch 3, 92.436975 % done
# 0 a, whe chroptmas of of come ye pay
# carone in bow all whese that christmas
# vooy the the inder is alles da lace,
#
# hourind a prilling hills in sneow aroidd!
# a'y ba christmas
#
# pening the downy renovas laye jlow heers th fease" her and of san
# u youre the hildnay and norigh to horj on in crrow christmas
# Saved model to 'models/deepjingling-songwriter8_epoch3.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.371755361557007, Train Evaluation Criterion: 0.65625
# Epoch 4, 0.000000 % done
# aningi5
# rings
#
# b come apoas haigh a you
# !in gamys menlely
# by canter santion heell you plory calle
# a bot and dith, dha:w a wenu you chrisets fo ling
# me your nartip,,
# wen i ank mawiding houd ga ba wea,h werure
# wat me dow
# and frarde's!
# o weate ) whe clow you wous
# hou christy beerre tra aiof christ bepe
# Minibatch: 66, Train Loss: 2.2646119594573975, Train Evaluation Criterion: 0.6953125
# Epoch 4, 4.988662 % done
# Minibatch: 132, Train Loss: 1.8731672763824463, Train Evaluation Criterion: 0.5234375
# Epoch 4, 9.977324 % done
# Minibatch: 198, Train Loss: 1.9245619773864746, Train Evaluation Criterion: 0.57421875
# Epoch 4, 14.965986 % done
# Minibatch: 264, Train Loss: 1.7413283586502075, Train Evaluation Criterion: 0.546875
# Epoch 4, 19.954649 % done
# gunk, wath the buld, and ull gren,, loth to of eveas but the tards in to the fomer. wore ow. bnowed and ofsed of churry being, and fond, has to with a do reing in dot a him he that! in homoe amoad all, suchis iot, for of doon and christmag him un was brering in lake sto in, more you sill be ip craye
# Minibatch: 330, Train Loss: 1.6883691549301147, Train Evaluation Criterion: 0.52734375
# Epoch 4, 24.943311 % done
# Minibatch: 396, Train Loss: 1.8429280519485474, Train Evaluation Criterion: 0.49609375
# Epoch 4, 29.931973 % done
# Minibatch: 462, Train Loss: 1.9594719409942627, Train Evaluation Criterion: 0.62109375
# Epoch 4, 34.920635 % done
# Minibatch: 528, Train Loss: 1.8230633735656738, Train Evaluation Criterion: 0.51953125
# Epoch 4, 39.909297 % done
# !
#
# "i kpraved, like shaday to must in of buven obent his evighous outs where thas it look all kdemn of one of thouded he in bablod out a popayed in cowen no had to sparned that a feing, was glo intant and its strame.
#
# "i sencund to thet dewpinised of mrnk said with i post."
#
# hat no was thineswur; the
# Minibatch: 594, Train Loss: 1.7481580972671509, Train Evaluation Criterion: 0.515625
# Epoch 4, 44.897959 % done
# Minibatch: 660, Train Loss: 1.8103716373443604, Train Evaluation Criterion: 0.54296875
# Epoch 4, 49.886621 % done
# Minibatch: 726, Train Loss: 1.9339747428894043, Train Evaluation Criterion: 0.625
# Epoch 4, 54.875283 % done
# Minibatch: 792, Train Loss: 1.776141881942749, Train Evaluation Criterion: 0.5546875
# Epoch 4, 59.863946 % done
# : to us the campinafe. it's frecer prise, you amd omer from!
#
# and, e! he night and weor cummr winter ternem harls yee , ,6ow ner, trone i i ly carners, was lewt snat whiv) non't lustda teaty to look upbfy good zust  the bogkr; wack indelpuk. pow." "
#
# that from bird as now, and goolis. nothing."
#
# hold
# Minibatch: 858, Train Loss: 1.6318325996398926, Train Evaluation Criterion: 0.48046875
# Epoch 4, 64.852608 % done
# Minibatch: 924, Train Loss: 1.6709942817687988, Train Evaluation Criterion: 0.4921875
# Epoch 4, 69.841270 % done
# Minibatch: 990, Train Loss: 1.6183241605758667, Train Evaluation Criterion: 0.50390625
# Epoch 4, 74.829932 % done
# Minibatch: 1056, Train Loss: 1.9965813159942627, Train Evaluation Criterion: 0.56640625
# Epoch 4, 79.818594 % done
# zy his sofs sor beleeper posted had gandy pon sold stonger. all pot to fard and her strok:
#
# "the tird. "the parpar, that the dasots dakeds," as what stots a-wird have awer that shour of the speck out it fat ester! and so lought town. but he one but thid prode noolder. so that she in usfied evan find
# Minibatch: 1122, Train Loss: 2.0075316429138184, Train Evaluation Criterion: 0.6015625
# Epoch 4, 84.807256 % done
# Minibatch: 1188, Train Loss: 1.8779590129852295, Train Evaluation Criterion: 0.56640625
# Epoch 4, 89.795918 % done
# Minibatch: 1254, Train Loss: 1.8299427032470703, Train Evaluation Criterion: 0.5703125
# Epoch 4, 94.784580 % done
# Minibatch: 1320, Train Loss: 1.9463138580322266, Train Evaluation Criterion: 0.5703125
# Epoch 4, 99.773243 % done
# , to the pose, and the ortabanion. and not the :darr hearlate, hosazed and thought seeround shart weme he tell retristing on the mollisal keerly one." he tall. have artiber thie were a had a loke had a head hrib through it to his oesed on that the abution, wordmening. clighted for cound of had musina
# Saved model to 'models/deepjingling-storyteller8_epoch4.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.8656126260757446, Train Evaluation Criterion: 0.53515625
# Epoch 5, 0.000000 % done
# 4eds: but artliener been not it had iverpromian upon i too down ever ther hown let or thee pacted thee. nober say. a cave my hadh he thoue huming he all heads, seepity had buy there himned a cost caeture. make, through, he was yearing virice whene cread flouthing alore home fune the gad even that at
# Minibatch: 11, Train Loss: 2.0184807777404785, Train Evaluation Criterion: 0.58984375
# Epoch 5, 9.243697 % done
# Minibatch: 22, Train Loss: 2.161985158920288, Train Evaluation Criterion: 0.61328125
# Epoch 5, 18.487395 % done
# Minibatch: 33, Train Loss: 2.296685218811035, Train Evaluation Criterion: 0.6640625
# Epoch 5, 27.731092 % done
# muul someny hale clealil, !tings in mad all fils dilifn, up seepion astagh go him-wa through one bo askon roun epory jessly it
# of mininurs is practle, grilut, if grlated
# why ip kill.
# da a new ner with over are astivial, on of all hraomn..
# 5ule, ajker.
# cto to a seota long and this righ throogh the  th
# Minibatch: 44, Train Loss: 1.6589447259902954, Train Evaluation Criterion: 0.49609375
# Epoch 5, 36.974790 % done
# Minibatch: 55, Train Loss: 1.8742965459823608, Train Evaluation Criterion: 0.58984375
# Epoch 5, 46.218487 % done
# Minibatch: 66, Train Loss: 1.942451000213623, Train Evaluation Criterion: 0.56640625
# Epoch 5, 55.462185 % done
# Minibatch: 77, Train Loss: 2.074244499206543, Train Evaluation Criterion: 0.578125
# Epoch 5, 64.705882 % done
# 'nd
# ptlee.
# i roon ale me
# what sleighrall, fotf |-lings christmas
# man in suns
# snowfmn that'm, let pum,
# gall pum.
# whom wren-cpristle boeigs made bark. and bey my
# tree, sole a trann-,o tree
# ?go crow, fants and histrose' pharth sleetle his christmas long hip
# houst sore tree in bowh pum
# of and dear for in
# Minibatch: 88, Train Loss: 2.016265869140625, Train Evaluation Criterion: 0.59375
# Epoch 5, 73.949580 % done
# Minibatch: 99, Train Loss: 1.883239507675171, Train Evaluation Criterion: 0.515625
# Epoch 5, 83.193277 % done
# Minibatch: 110, Train Loss: 1.8406356573104858, Train Evaluation Criterion: 0.55859375
# Epoch 5, 92.436975 % done
# 'nd winking come neallingss ho waymer
#  duviry christmas, in miytra bellingss, as the twarring when christmas$ the pimings when a swow and christmas
# it's a browher
# in a vimk a gerphrentored which and all it all th
# linded snows
#  leph day sans!
# witherly laych
#
# men in the new all it's in senta mudby leve
# Saved model to 'models/deepjingling-songwriter8_epoch5.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.8038082122802734, Train Evaluation Criterion: 0.5703125
# Epoch 6, 0.000000 % done
# orn pir?hs me christmas a di9 geasolentied so tone
# with you and christmas the fon: the pantings
# draids bitting.
#
# ecentans to met.tdees agorny of a may would come a ganta go
#  now dinys',
# year
# we alls lhapions ourles a fwaten santa a ladigs as a christmas prie godding
# on a much a cearey'gheal a leake h
# Minibatch: 11, Train Loss: 1.8017113208770752, Train Evaluation Criterion: 0.546875
# Epoch 6, 9.243697 % done
# Minibatch: 22, Train Loss: 2.0073025226593018, Train Evaluation Criterion: 0.57421875
# Epoch 6, 18.487395 % done
# Minibatch: 33, Train Loss: 2.1716456413269043, Train Evaluation Criterion: 0.66796875
# Epoch 6, 27.731092 % done
#
# thu bibdn,
# hoge holey
# were born you're children ca cope-of light vale soun dill
# ang an2ethil,
# "the sounch, so bong
# houedien caple
# fatest qetre
# and ba, sack!
# sletts.
# with thuhe
# eves hail your pul on is retary
# can we,
# blite feollu, are are are winla wise matern, and sto wisk song belet laokmaled a ba
# Minibatch: 44, Train Loss: 1.5622574090957642, Train Evaluation Criterion: 0.5078125
# Epoch 6, 36.974790 % done
# Minibatch: 55, Train Loss: 1.629347562789917, Train Evaluation Criterion: 0.5
# Epoch 6, 46.218487 % done
# Minibatch: 66, Train Loss: 1.840651512145996, Train Evaluation Criterion: 0.53125
# Epoch 6, 55.462185 % done
# Minibatch: 77, Train Loss: 1.8971153497695923, Train Evaluation Criterion: 0.55078125
# Epoch 6, 64.705882 % done
# um
# pher bed thome christmase the mo whypeering
# lows ruse,, me's us the bughl of that by!
# plobing the wolder the all
# bvee to even that for the dop of hearty for the other christmas thy proaldfel!
# ko that the loadladfould wonderful bra of anlewer christmas
# pum!alings aven it's thu ambn
# christmas part
# Minibatch: 88, Train Loss: 1.8485305309295654, Train Evaluation Criterion: 0.53515625
# Epoch 6, 73.949580 % done
# Minibatch: 99, Train Loss: 1.7488442659378052, Train Evaluation Criterion: 0.484375
# Epoch 6, 83.193277 % done
# Minibatch: 110, Train Loss: 1.6474674940109253, Train Evaluation Criterion: 0.50390625
# Epoch 6, 92.436975 % done
# ume a christmas a menter oning!
#
# up his sadsent hear himing of a landing s feathered
#  daying
# men with a happy when comes of a gildings pallings
# and chriussmas trieght
# en all a pile birds bech duwn and birds,
# lird, a pirtle laying
# walking nawing gwanding
# he fallingings of the christmas, the dayes
# come
# Saved model to 'models/deepjingling-songwriter8_epoch6.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.8107450008392334, Train Evaluation Criterion: 0.5546875
# Epoch 7, 0.000000 % done
# ge fidewasunes the yarta fest were wondering
# .aras fe
# wintifet
# when anl be pear we'll i we born mays
# a know of your a merry snowma
# 1up yeasing that be no day.s
# sium gave, walk,
# o the mantan
#  will christmasings a merry
# live we christmas
# hear the mell me
# is your norly to your knowas houd come sure te h
# Minibatch: 11, Train Loss: 1.7451218366622925, Train Evaluation Criterion: 0.484375
# Epoch 7, 9.243697 % done
# Minibatch: 22, Train Loss: 1.852314829826355, Train Evaluation Criterion: 0.5546875
# Epoch 7, 18.487395 % done
# Minibatch: 33, Train Loss: 2.1165482997894287, Train Evaluation Criterion: 0.625
# Epoch 7, 27.731092 % done
# "" mess him sneogh geese from with king
# the kye pow in aleluth of stan|s
# light
# driors, to  onnesy news wickrun i've frech stageed.
#
# hail a made!
#
# cerh him a sin'nout bewamic!
# he bt, nauein, would,
# watch with the for thit christ the gressit anl ch4cklered breylan6s your tarimed
# join man, ma$en to holl
# Minibatch: 44, Train Loss: 1.438786506652832, Train Evaluation Criterion: 0.46484375
# Epoch 7, 36.974790 % done
# Minibatch: 55, Train Loss: 1.624064564704895, Train Evaluation Criterion: 0.52734375
# Epoch 7, 46.218487 % done
# Minibatch: 66, Train Loss: 1.8137180805206299, Train Evaluation Criterion: 0.515625
# Epoch 7, 55.462185 % done
# Minibatch: 77, Train Loss: 1.8861136436462402, Train Evaluation Criterion: 0.56640625
# Epoch 7, 64.705882 % done
# 's lo low
# nong
#
# jistle lot it sneg wonder
# holly plowring
# a sump, jum pum pum pum pum,
#
# a from the home
# plemp comes, o my speads to me jum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum,
# it's toe my up
# christmas bestees sleigh shire the smime
# to mittle bhem hen's you
# ding its
# Minibatch: 88, Train Loss: 1.8401449918746948, Train Evaluation Criterion: 0.53515625
# Epoch 7, 73.949580 % done
# Minibatch: 99, Train Loss: 1.6773309707641602, Train Evaluation Criterion: 0.5078125
# Epoch 7, 83.193277 % done
# Minibatch: 110, Train Loss: 1.5050755739212036, Train Evaluation Criterion: 0.42578125
# Epoch 7, 92.436975 % done
# her of christmas we true all be you're the ruming
# 8 christmas happings a mirse heaven wish the world.
#
# happy gear birdss will christmas
# happy day is a holy and swifridgidging that thuntre the most santa christmas.we bellelm
#
# mrsy a lay hear a happy a say of christmas which a christmas
# by rue know
# all
# Saved model to 'models/deepjingling-songwriter8_epoch7.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.427947759628296, Train Evaluation Criterion: 0.62890625
# Epoch 8, 0.000000 % done
# qididing are sent are ten
# wish the trie and every down! bu vircidizs a live rencud daying, nover and halling a seiter way
# we all sphill the christmas christmas
# we'll santa cha la le of for jeatiep hopes
# pancers and snowmarting time
# 3ll a tarpield listen year
# 3 adwiny tree a mabe have ride! all he wal
# Minibatch: 66, Train Loss: 2.093050718307495, Train Evaluation Criterion: 0.6171875
# Epoch 8, 4.988662 % done
# Minibatch: 132, Train Loss: 1.5434569120407104, Train Evaluation Criterion: 0.453125
# Epoch 8, 9.977324 % done
# Minibatch: 198, Train Loss: 1.6447714567184448, Train Evaluation Criterion: 0.5
# Epoch 8, 14.965986 % done
# Minibatch: 264, Train Loss: 1.5234302282333374, Train Evaluation Criterion: 0.453125
# Epoch 8, 19.954649 % done
# 6 ofg inlip him at betting diver the had, adsimmer, ent, prespored fearing, the mezice of adoach for the dadis it; and thimself;" nosts twach said your has up room qnauter.
#
# the house words he leck. when throught abway, and save he home up lept in us, and word, dirst no like; and havade in in doer di
# Minibatch: 330, Train Loss: 1.4999014139175415, Train Evaluation Criterion: 0.47265625
# Epoch 8, 24.943311 % done
# Minibatch: 396, Train Loss: 1.8321049213409424, Train Evaluation Criterion: 0.51171875
# Epoch 8, 29.931973 % done
# Minibatch: 462, Train Loss: 1.8355073928833008, Train Evaluation Criterion: 0.56640625
# Epoch 8, 34.920635 % done
# Minibatch: 528, Train Loss: 1.6355003118515015, Train Evaluation Criterion: 0.4609375
# Epoch 8, 39.909297 % done
# spered comuch out him moch is twenth look hand.
#
# but took to anvering it of it was no not.
#
# which there would tan now for the cwild an enend she kinds childn't not song, christmas upon who king handned jood, whoh me other of tallocly ol, this seemer, monly to you."
#
# "rightable pling for nases, spirit
# Minibatch: 594, Train Loss: 1.6134579181671143, Train Evaluation Criterion: 0.54296875
# Epoch 8, 44.897959 % done
# Minibatch: 660, Train Loss: 1.6188373565673828, Train Evaluation Criterion: 0.4765625
# Epoch 8, 49.886621 % done
# Minibatch: 726, Train Loss: 1.8581411838531494, Train Evaluation Criterion: 0.56640625
# Epoch 8, 54.875283 % done
# Minibatch: 792, Train Loss: 1.658049464225769, Train Evaluation Criterion: 0.5
# Epoch 8, 59.863946 % done
# found, on there road, and when," said a sus str rellcock."
#
# "i'm touch," said see."
#
# this found upon a chang."
#
# "got nows christmas bebmen interoon fitfer the o my fullpes thought. "there the feraspels the let fing of hall brerite feite call you. treesessier seemly i'll helm enought and larm lutter l
# Minibatch: 858, Train Loss: 1.4907426834106445, Train Evaluation Criterion: 0.4609375
# Epoch 8, 64.852608 % done
# Minibatch: 924, Train Loss: 1.5453263521194458, Train Evaluation Criterion: 0.50390625
# Epoch 8, 69.841270 % done
# Minibatch: 990, Train Loss: 1.3906325101852417, Train Evaluation Criterion: 0.44140625
# Epoch 8, 74.829932 % done
# Minibatch: 1056, Train Loss: 1.9141098260879517, Train Evaluation Criterion: 0.51953125
# Epoch 8, 79.818594 % done
# 3 was depo, and him at grate ponlifest on the bir of his soft ricch as white i dencut boping happofs for the suppoct and him caulder as us dar braxrused the nangerer at alow stey a, as dan rafged of sureier hand pleep having your heartetatives. sod. the sone, spartain of good to the good of the wand
# Minibatch: 1122, Train Loss: 1.928949236869812, Train Evaluation Criterion: 0.5625
# Epoch 8, 84.807256 % done
# Minibatch: 1188, Train Loss: 1.7156625986099243, Train Evaluation Criterion: 0.51171875
# Epoch 8, 89.795918 % done
# Minibatch: 1254, Train Loss: 1.8480945825576782, Train Evaluation Criterion: 0.55859375
# Epoch 8, 94.784580 % done
# Minibatch: 1320, Train Loss: 1.830989956855774, Train Evaluation Criterion: 0.53515625
# Epoch 8, 99.773243 % done
#
#
# screqtoveer. he sama artean, the darkxar the guver believed."
#
# but, one? they tin well not him, but doub had gest of the houses. samo iull giverless of the honier of the crupt; inwinding, head and lofe parther ploulds had en. eveny cipoven of in every among him come the tame in his orn dim and lept
# Saved model to 'models/deepjingling-storyteller8_epoch8.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.7317010164260864, Train Evaluation Criterion: 0.4765625
# Epoch 9, 0.000000 % done
# quws shill doon. but,
# knubs.
#
# he was he had waird" day alald auted i tremember fearing of yelthing the't must fiend.
#
# culliened his neemer, and ineaver that had geing.
#
# "had seal under see pilace tendle, that begqlulled spul liend. the low, which had freltlienced on the truttle. "it one humsered the
# Minibatch: 11, Train Loss: 1.6936753988265991, Train Evaluation Criterion: 0.52734375
# Epoch 9, 9.243697 % done
# Minibatch: 22, Train Loss: 1.921349048614502, Train Evaluation Criterion: 0.53125
# Epoch 9, 18.487395 % done
# Minibatch: 33, Train Loss: 2.160961627960205, Train Evaluation Criterion: 0.625
# Epoch 9, 27.731092 % done
#  but snow
# ensao1 old suff have rew
# in the age. and an untrankel e6rirored, reasivent than resolaspys. mornent heads
# garss, the sile. bo?sters up one (ba an inilesion, gavelles,
# all his sillnuce
# thickly
# grressed to there's some stunenoly when the srokad there from diblefred; the conbanisher.
# 9e nrun,
#
# Minibatch: 44, Train Loss: 1.5312954187393188, Train Evaluation Criterion: 0.4921875
# Epoch 9, 36.974790 % done
# Minibatch: 55, Train Loss: 1.7589187622070312, Train Evaluation Criterion: 0.546875
# Epoch 9, 46.218487 % done
# Minibatch: 66, Train Loss: 1.7771316766738892, Train Evaluation Criterion: 0.5234375
# Epoch 9, 55.462185 % done
# Minibatch: 77, Train Loss: 1.8716790676116943, Train Evaluation Criterion: 0.56640625
# Epoch 9, 64.705882 % done
# zenst resum pumpum
# pumpumpum
# pumpum pumpum pumpumpum pumpum, 6mpneingong!;
# then't't be look hroming,
# pum pumpumpul
# pumpum pumpum
# pumpum.tk of jum pumppumum pum pumpumpum
# pusosfy
#
#
# tho dothon thy pumpus pumpus
# pumpum pumpumppum
# pumpumppum pumppum,
# of to refum pumpul pumpumml pumpum pumpum pumppumaptu
# Minibatch: 88, Train Loss: 1.8468477725982666, Train Evaluation Criterion: 0.515625
# Epoch 9, 73.949580 % done
# Minibatch: 99, Train Loss: 1.6716225147247314, Train Evaluation Criterion: 0.4765625
# Epoch 9, 83.193277 % done
# Minibatch: 110, Train Loss: 1.6337199211120605, Train Evaluation Criterion: 0.4921875
# Epoch 9, 92.436975 % done
# linging pear of trantling
# are a trake christmas tree
#
# fipalling a in the some repeared in my
#  a pulared
# it's cimney a regil no trath of merry
#  by be a end i tay a filling a aridgest
# is the see days
#
# thilk many him!
# 6 trees,
# and a guntle bill reflinch a voice
#
# our ara pridest to waitly
# i poding and en
# Saved model to 'models/deepjingling-songwriter8_epoch9.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.6716103553771973, Train Evaluation Criterion: 0.53515625
# Epoch 10, 0.000000 % done
# ing naister
# "he with town
# that we bells!
# and the mest tellingss prealson
# the jay retoned moy a days a way sunarle little beird, we'll a best grunm light dugle lant a cemterd of you your day
#
# eaven do imen on christmas new a looking eark, we'll we're daying
# christmas a amefur we christmas hukries happ
# Minibatch: 11, Train Loss: 1.6530239582061768, Train Evaluation Criterion: 0.48828125
# Epoch 10, 9.243697 % done
# Minibatch: 22, Train Loss: 1.8240300416946411, Train Evaluation Criterion: 0.51171875
# Epoch 10, 18.487395 % done
# Minibatch: 33, Train Loss: 2.011461019515991, Train Evaluation Criterion: 0.609375
# Epoch 10, 27.731092 % done
# 0ln snow srowzd valk and pey, we for the womed
# if the lest, hye. from dey fill ba potends of the fin,
# for wire grights ghose to estarly and glacehtless fighterned in mo as, the molds you're gan his grace pronniesase.
# snesses,
# we're walk of the hirse in his lite!
# or! ko ake!
# by
# by snubp hub grasts kan
# Minibatch: 44, Train Loss: 1.4083789587020874, Train Evaluation Criterion: 0.453125
# Epoch 10, 36.974790 % done
# Minibatch: 55, Train Loss: 1.5229893922805786, Train Evaluation Criterion: 0.484375
# Epoch 10, 46.218487 % done
# Minibatch: 66, Train Loss: 1.7267826795578003, Train Evaluation Criterion: 0.50390625
# Epoch 10, 55.462185 % done
# Minibatch: 77, Train Loss: 1.743037223815918, Train Evaluation Criterion: 0.53125
# Epoch 10, 64.705882 % done
# ) the care,
# it's toon,
#
# out "gold the earth
# rody to nost grow and lother!
# jingle belling!
# o christmas of the christmas trite hhart made!
# but the paw -times rote,
# it's the long,
# it's my
# when a of buts broshing.
# |ah and tuned of everyther kidditda bells,
# sweo.
# o love sings
# pum
# pum
# pum pum.
# clow my magu
# Minibatch: 88, Train Loss: 1.787857174873352, Train Evaluation Criterion: 0.53125
# Epoch 10, 73.949580 % done
# Minibatch: 99, Train Loss: 1.5965150594711304, Train Evaluation Criterion: 0.5078125
# Epoch 10, 83.193277 % done
# Minibatch: 110, Train Loss: 1.4186789989471436, Train Evaluation Criterion: 0.3984375
# Epoch 10, 92.436975 % done
# s shake drift crinch the prides sings we bellidging
# 3 sings
# and the christmas
# the sentight
# light
# birds swiding
# rings
# and out in your doves
#
# and landing
# k down of a christmas
# with bucking is comings
# a might
#
# just pamping singings
#
# happy on my way
# and a laying
# when santa partridge and year tentre snow
# Saved model to 'models/deepjingling-songwriter8_epoch10.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.693665623664856, Train Evaluation Criterion: 0.51171875
# Epoch 11, 0.000000 % done
# 8 calling is a happy a lay,
# pease pear from a pary flimes all be gilden
# over the little ring a merry sleigh-was frumscrist are christmas
# the christmas
# treesgay of a partide to calling snow santa's billing!
#
# that you,
# and engiding:
#
# god a parteridge of a lew mangold sent and christmas
# and year
# cringy
# Minibatch: 11, Train Loss: 1.6695690155029297, Train Evaluation Criterion: 0.5
# Epoch 11, 9.243697 % done
# Minibatch: 22, Train Loss: 1.7705570459365845, Train Evaluation Criterion: 0.5078125
# Epoch 11, 18.487395 % done
# Minibatch: 33, Train Loss: 1.8054680824279785, Train Evaluation Criterion: 0.546875
# Epoch 11, 27.731092 % done
# gy, emblical him
# with down, sing
# 8 enehay
# old the gritch in a christ.
# m' the night wise sliage out mariy
# were mistletack of gordightman wance by hid seak moused drry!
# in made as him napwer child full reother day he ran grinch,
# with a a jerrendil'd mon-sfore silvered
# let's stars of vanin been from our
# Minibatch: 44, Train Loss: 1.392684817314148, Train Evaluation Criterion: 0.453125
# Epoch 11, 36.974790 % done
# Minibatch: 55, Train Loss: 1.4603031873703003, Train Evaluation Criterion: 0.46484375
# Epoch 11, 46.218487 % done
# Minibatch: 66, Train Loss: 1.6266456842422485, Train Evaluation Criterion: 0.453125
# Epoch 11, 55.462185 % done
# Minibatch: 77, Train Loss: 1.6457799673080444, Train Evaluation Criterion: 0.48828125
# Epoch 11, 64.705882 % done
# y motter wonderful teme
# night on the bleaming
# |and tarny up presum pum pum pum
# may ocking
# -right dream,
# pa rum pum pum pum pum pum pum pum pum pum pum pum pum pum pum
# this but a clord jack heaven grote bell drack, ow're th' ferime
# 8ay
# rum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pu
# Minibatch: 88, Train Loss: 1.688075304031372, Train Evaluation Criterion: 0.51953125
# Epoch 11, 73.949580 % done
# Minibatch: 99, Train Loss: 1.6258784532546997, Train Evaluation Criterion: 0.44140625
# Epoch 11, 83.193277 % done
# Minibatch: 110, Train Loss: 1.3024333715438843, Train Evaluation Criterion: 0.390625
# Epoch 11, 92.436975 % done
# lid's a snow
# chimnen pumver time the swining
# 6 snow
# and a be my onididad
# your drind tonight
# and crooking a wair
# kinding.
#
# silver, spay their you silver, so for mornings to a now all a happy christmas brings
# 4 christmas and tade of every christmas knee the snow rings
# "santa claus, i'm christmas
# d the
# Saved model to 'models/deepjingling-songwriter8_epoch11.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.495307207107544, Train Evaluation Criterion: 0.64453125
# Epoch 12, 0.000000 % done
# them watter
# that with happy down
# ) four caradion it's the hop,
# awn't be a navidad
# and a day
# and sent a men!
# wide tree a waits of you christmas
# the lord of white was land a new in his lame
# 3 leaped to you a white
#
# snow happies christmas,
# it's a pirtridge pant wonderful for no pauts dradled presiming
# p
# Minibatch: 66, Train Loss: 2.0453109741210938, Train Evaluation Criterion: 0.625
# Epoch 12, 4.988662 % done
# Minibatch: 132, Train Loss: 1.5274481773376465, Train Evaluation Criterion: 0.4765625
# Epoch 12, 9.977324 % done
# Minibatch: 198, Train Loss: 1.6005394458770752, Train Evaluation Criterion: 0.48046875
# Epoch 12, 14.965986 % done
# Minibatch: 264, Train Loss: 1.4099818468093872, Train Evaluation Criterion: 0.4375
# Epoch 12, 19.954649 % done
# warn and dark are home. "thought drears, they had he hose and the no lasy with a leath christmas, as scrooge crumbation, and donder, and it have exmarmed instiously forgettered his scrrooge in its bitter exkomed from with that goep as he was emerly his reatige to a head holtly are.
#
# "left upon a sufp
# Minibatch: 330, Train Loss: 1.4033851623535156, Train Evaluation Criterion: 0.44140625
# Epoch 12, 24.943311 % done
# Minibatch: 396, Train Loss: 1.7123898267745972, Train Evaluation Criterion: 0.4765625
# Epoch 12, 29.931973 % done
# Minibatch: 462, Train Loss: 1.7869406938552856, Train Evaluation Criterion: 0.55859375
# Epoch 12, 34.920635 % done
# Minibatch: 528, Train Loss: 1.5728199481964111, Train Evaluation Criterion: 0.4453125
# Epoch 12, 39.909297 % done
# ould it, and was spirit pation of no side in a spirit.
#
# the woke to a fucely pore bride, in might my fire sume enter gration look upon it would dourdouty and spurits is nothing a spirit's so rai, and its cin hearted he was better amain. "this was madied.
#
# "home shard, i moming at the head, and a suma
# Minibatch: 594, Train Loss: 1.513035774230957, Train Evaluation Criterion: 0.4921875
# Epoch 12, 44.897959 % done
# Minibatch: 660, Train Loss: 1.4358043670654297, Train Evaluation Criterion: 0.44921875
# Epoch 12, 49.886621 % done
# Minibatch: 726, Train Loss: 1.8171623945236206, Train Evaluation Criterion: 0.55859375
# Epoch 12, 54.875283 % done
# Minibatch: 792, Train Loss: 1.6204590797424316, Train Evaluation Criterion: 0.515625
# Epoch 12, 59.863946 % done
# . there you'll have riman a brarcerse it, there cum old every hand.
#
# "i rye, and blessing them for i don't good all."
#
# "i's trown 5o terry up for devialight carain of given, very agrised a brever in the aprobt the obks twigain, that own conelip that, and be?
#
# "richinm his descrem:ly, every eepy lock
# Minibatch: 858, Train Loss: 1.429887056350708, Train Evaluation Criterion: 0.42578125
# Epoch 12, 64.852608 % done
# Minibatch: 924, Train Loss: 1.5009562969207764, Train Evaluation Criterion: 0.44140625
# Epoch 12, 69.841270 % done
# Minibatch: 990, Train Loss: 1.3412504196166992, Train Evaluation Criterion: 0.41796875
# Epoch 12, 74.829932 % done
# Minibatch: 1056, Train Loss: 1.7740308046340942, Train Evaluation Criterion: 0.51953125
# Epoch 12, 79.818594 % done
# ; as this seeming emother dester. "dout the powered what were a door, it had tell could be!
#
# the hept piped at the trode and bow -- cand by away. himmade; up pot on the door the run by could clem his than all the window the dear band wrote so his window the may vilt glaible ratter of the thinctralive
# Minibatch: 1122, Train Loss: 1.7567851543426514, Train Evaluation Criterion: 0.57421875
# Epoch 12, 84.807256 % done
# Minibatch: 1188, Train Loss: 1.7289621829986572, Train Evaluation Criterion: 0.53515625
# Epoch 12, 89.795918 % done
# Minibatch: 1254, Train Loss: 1.6859759092330933, Train Evaluation Criterion: 0.53515625
# Epoch 12, 94.784580 % done
# Minibatch: 1320, Train Loss: 1.7318189144134521, Train Evaluation Criterion: 0.5
# Epoch 12, 99.773243 % done
# . seedon in his pan me miss. stures from the hards.
#
# "looked his revited, thuck the air, potered at light out into a injussand the gradenly hut, larkens of anceress of might lifition," iny she that the gilling with bagion and inspend to parse, he glid in thy oscandful and tanity more, behind hidly a
# Saved model to 'models/deepjingling-storyteller8_epoch12.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.6529521942138672, Train Evaluation Criterion: 0.51171875
# Epoch 13, 0.000000 % done
# hs was alnosened only full heard of the aural, of see heaven to the slubs prove, the fon through thee and darkhude on born when in all fariate, and fiend was primation. he cluborful gewn and the cuss of it. he is gothers was one, but are fleared adsmand."
#
# he as digether?
#
# the ded perand ray might th
# Minibatch: 11, Train Loss: 1.6397343873977661, Train Evaluation Criterion: 0.4921875
# Epoch 13, 9.243697 % done
# Minibatch: 22, Train Loss: 1.7580934762954712, Train Evaluation Criterion: 0.484375
# Epoch 13, 18.487395 % done
# Minibatch: 33, Train Loss: 2.047264814376831, Train Evaluation Criterion: 0.59765625
# Epoch 13, 27.731092 % done
# ?
# "grinch,
# to give ranius to sing ismech santa
# trabe to a greatmineher,
# xendlet for the light terrawy becurtres
# lessor-ently as cear,
# been arred jinkinch, thure, that her'n to ancast no,
# of gill, and th're hase as reindeers to there?
# say to meling rises is geese;"r call. staving of here,
# "sea!
# he-lit
# Minibatch: 44, Train Loss: 1.4701274633407593, Train Evaluation Criterion: 0.484375
# Epoch 13, 36.974790 % done
# Minibatch: 55, Train Loss: 1.5928070545196533, Train Evaluation Criterion: 0.53515625
# Epoch 13, 46.218487 % done
# Minibatch: 66, Train Loss: 1.728417992591858, Train Evaluation Criterion: 0.4921875
# Epoch 13, 55.462185 % done
# Minibatch: 77, Train Loss: 1.7544323205947876, Train Evaluation Criterion: 0.53515625
# Epoch 13, 64.705882 % done
# pag heard
# di,
# o light do be tree the noose
# then jum pum pum pum pum
# pum
# pum
# pum pum
# pum
# pum
# pum pum pum
# pum pum
# pum
# pum
# pum
# pum
# pum pum pum!pppum pum,
# mersimy one home and must of a blowher see,
# thy soughtro5
# and woger
# -to me horse, the christmas tree
# there's fige of the replring led rightless how
# Minibatch: 88, Train Loss: 1.765424132347107, Train Evaluation Criterion: 0.50390625
# Epoch 13, 73.949580 % done
# Minibatch: 99, Train Loss: 1.5977636575698853, Train Evaluation Criterion: 0.48828125
# Epoch 13, 83.193277 % done
# Minibatch: 110, Train Loss: 1.5248184204101562, Train Evaluation Criterion: 0.4609375
# Epoch 13, 92.436975 % done
# zing warding me a love of the merry sleigh in a kings in you;
# 38 larus with a bealey happy weaving to christmas,
#
# o bell a christmas,
# and the divinings: sing a giddyer let dillings tree
# o can a way
# 3 year of the pass passen tree swoven
# and merry
# was a pridings of thu orning propper plentral
# sent a ma
# Saved model to 'models/deepjingling-songwriter8_epoch13.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.6496986150741577, Train Evaluation Criterion: 0.51953125
# Epoch 14, 0.000000 % done
# jingle belling of me and power,
# triming
# white tree.
# k christmasaving
# can diddut your own a pibrusion jingle may giddye
# and good nustore
# on i ssnow of the heart,
# mury christmas up tree
# happy ur!
# and made the day,
# our young
# "certaban,
# he lune christmas! jobsanta christmas,
# we be rapos, did comes and do
# Minibatch: 11, Train Loss: 1.5906580686569214, Train Evaluation Criterion: 0.50390625
# Epoch 14, 9.243697 % done
# Minibatch: 22, Train Loss: 1.6210193634033203, Train Evaluation Criterion: 0.50390625
# Epoch 14, 18.487395 % done
# Minibatch: 33, Train Loss: 1.8888899087905884, Train Evaluation Criterion: 0.5546875
# Epoch 14, 27.731092 % done
# 7re! with thee it could really as the filf.
# their canicth, wish als-ins enter, that a gleaminöan' reindeer snow
# howm, now santa gidjydure lay,
# santa claus to highest, and of honour.
#
# now a now a dill af the grinch greet mightbe mistletoe,
# santa
# eabor
# strees to new s-ee, from that we congest as gloch
# Minibatch: 44, Train Loss: 1.3605329990386963, Train Evaluation Criterion: 0.4453125
# Epoch 14, 36.974790 % done
# Minibatch: 55, Train Loss: 1.4612001180648804, Train Evaluation Criterion: 0.44140625
# Epoch 14, 46.218487 % done
# Minibatch: 66, Train Loss: 1.5987999439239502, Train Evaluation Criterion: 0.46875
# Epoch 14, 55.462185 % done
# Minibatch: 77, Train Loss: 1.5180937051773071, Train Evaluation Criterion: 0.46875
# Epoch 14, 64.705882 % done
# 9 sreigh,
# then hally christmas tree,
# born the cumorqully! my prum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum:on the such,
# it's he
# pod of grom home will be up on young
# you's jum pum
# and as my sing  in the melaypy in open walk.
# 3qorsed
# as
# Minibatch: 88, Train Loss: 1.6208761930465698, Train Evaluation Criterion: 0.4921875
# Epoch 14, 73.949580 % done
# Minibatch: 99, Train Loss: 1.5419049263000488, Train Evaluation Criterion: 0.45703125
# Epoch 14, 83.193277 % done
# Minibatch: 110, Train Loss: 1.2881453037261963, Train Evaluation Criterion: 0.3828125
# Epoch 14, 92.436975 % done
# 6d a most chimney come in the snowing
# 3 christmas wonders a laying,
# with a every drewm when ringing jecking
# ling singing
# i like it enter santa's run winds a leass
# will come jeading some swimding,
# i'm now spirit know for mather hens
# w a daying
# 4 christmas,
# o christmas eve
# and a partring a quimming
#
#
#
#
# Saved model to 'models/deepjingling-songwriter8_epoch14.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.6448699235916138, Train Evaluation Criterion: 0.5078125
# Epoch 15, 0.000000 % done
# 4re
# christmas tried of my live
# birds
# i don't the dancing to have the airs
#
# but i'm now the saw i'd brighta must swan under the lichs dancing
# and tidy be rewend,
# christ to goe a many paper walking a leaping
# jesus day,
# and and daying
# and to know with you
#
# know thee from a happy heart unry a merry doves
# Minibatch: 11, Train Loss: 1.4893075227737427, Train Evaluation Criterion: 0.43359375
# Epoch 15, 9.243697 % done
# Minibatch: 22, Train Loss: 1.6442816257476807, Train Evaluation Criterion: 0.453125
# Epoch 15, 18.487395 % done
# Minibatch: 33, Train Loss: 1.7985268831253052, Train Evaluation Criterion: 0.5546875
# Epoch 15, 27.731092 % done
# .
#
# those hens let goss out:
# so to creeson sake in deather me;
# they clerk distrance
# how with the rose watchin' mess is left old beonters, or goodidad.
# harkin' angels again
# koce
# angience
# little "will go king in triume
# used touch a stirgest of daya snowman,
# out
# hone in blie?
#
# "there'll makes
# retoed a po
# Minibatch: 44, Train Loss: 1.3088490962982178, Train Evaluation Criterion: 0.421875
# Epoch 15, 36.974790 % done
# Minibatch: 55, Train Loss: 1.413629174232483, Train Evaluation Criterion: 0.45703125
# Epoch 15, 46.218487 % done
# Minibatch: 66, Train Loss: 1.6012946367263794, Train Evaluation Criterion: 0.5
# Epoch 15, 55.462185 % done
# Minibatch: 77, Train Loss: 1.5722672939300537, Train Evaluation Criterion: 0.484375
# Epoch 15, 64.705882 % done
# s of a looking dump
# make the most do the hosting and gild
# while i go christmas tree,
# but it's the :tay
# he's mea?
# o christmas tree,
# the lotter, christmas,
# and testime
#
# mold holly, fi oh you pum pum pum pum, um pum pum pum pum,
# um pum pum
# wool ev'n long of the  most mofe sight
# 4
# the caral the dues of
# Minibatch: 88, Train Loss: 1.6292054653167725, Train Evaluation Criterion: 0.484375
# Epoch 15, 73.949580 % done
# Minibatch: 99, Train Loss: 1.4900903701782227, Train Evaluation Criterion: 0.4453125
# Epoch 15, 83.193277 % done
# Minibatch: 110, Train Loss: 1.1488991975784302, Train Evaluation Criterion: 0.3359375
# Epoch 15, 92.436975 % done
# ful hear of a dear in the snow,
# and a santa babys birds
# a presend to dear the christmas,
# and her presend down the an ense bards
#
# pear tree
# 2 comber
# and you a inzer heart smile of christmas
# huse all the far,
# jingle bells
# 3 calling love me, here is you the swans happy barth jingle bells
#
# o come like a
# Saved model to 'models/deepjingling-songwriter8_epoch15.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# ...
# Epoch 94, 36.974790 % done
# Minibatch: 55, Train Loss: 0.7624273300170898, Train Evaluation Criterion: 0.23828125
# Epoch 94, 46.218487 % done
# Minibatch: 66, Train Loss: 1.108155608177185, Train Evaluation Criterion: 0.33203125
# Epoch 94, 55.462185 % done
# Minibatch: 77, Train Loss: 1.0429496765136719, Train Evaluation Criterion: 0.33203125
# Epoch 94, 64.705882 % done
# very mepty lo
# quick as light in his daybell!
# he would give that the moment is melical fire and glare
# with truth and flooping! a man-cisies at the world to eat to look a lot like christmas, the single world in jingle bell, this will holding your heart.
# |presents on my king
# pa rum pum pum pum pum,
# rum
# Minibatch: 88, Train Loss: 1.0956320762634277, Train Evaluation Criterion: 0.33203125
# Epoch 94, 73.949580 % done
# Minibatch: 99, Train Loss: 1.1513901948928833, Train Evaluation Criterion: 0.36328125
# Epoch 94, 83.193277 % done
# Minibatch: 110, Train Loss: 0.31608980894088745, Train Evaluation Criterion: 0.09375
# Epoch 94, 92.436975 % done
# ) with the hrasty gifts slippers
# happy new years from four eyes with a bring
# grandma's good door sing.
#
# giddy-yap cried with silver click
# |gave thee
# and the single cards and brighting
# hear the quickly sings and gold
# gonna so'll us, just come
# pa rum pum pum pum pum,
# rum pum pum pum pum
# there's a speed
# Saved model to 'models/deepjingling-songwriter8_epoch94.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.2688896656036377, Train Evaluation Criterion: 0.359375
# Epoch 95, 0.000000 % done
# de with mighty king
# 2 maids a milking
# 8 ladies dancing
# 9 maids a milking
# 7 swans a swemming
# 11 partridge in a pear tree
#
# on the fellow that's not christmas.
# h' never smile
# and fields as if you're happy and light,
# my leaves christmas as your knees
# we'll did the syng of gliding drinkin' with a mine, we
# Minibatch: 11, Train Loss: 1.068729043006897, Train Evaluation Criterion: 0.30078125
# Epoch 95, 9.243697 % done
# Minibatch: 22, Train Loss: 0.9870131611824036, Train Evaluation Criterion: 0.31640625
# Epoch 95, 18.487395 % done
# Minibatch: 33, Train Loss: 1.0687434673309326, Train Evaluation Criterion: 0.29296875
# Epoch 95, 27.731092 % done
# ) villager, i'm believe!
# |you're a di
# god! the found dear light all with mistletoely of a star, eyes
# all your steel
# in the influence of her back
#
# now one man i wish you a merry christmas out
# i'm know your head
# spould's make a grinds fastion ran outside out his geese a laying
# 9 golden rings
# 4 calling
# Minibatch: 44, Train Loss: 0.894498884677887, Train Evaluation Criterion: 0.27734375
# Epoch 95, 36.974790 % done
# Minibatch: 55, Train Loss: 0.8313182592391968, Train Evaluation Criterion: 0.234375
# Epoch 95, 46.218487 % done
# Minibatch: 66, Train Loss: 1.0317668914794922, Train Evaluation Criterion: 0.3203125
# Epoch 95, 55.462185 % done
# Minibatch: 77, Train Loss: 0.9988270998001099, Train Evaluation Criterion: 0.26953125
# Epoch 95, 64.705882 % done
# ous as looking for a fairytold years in the year
#
# oh long ago
# |what fun it is to ride
# in a one horse open sleigh
#
# it's the most it is to ride
# in a one horse open sleigh
#
#
# it's keep the fire but down the chimney tonight!
# |it's he'll be beckinridge to never ride
# to see the searing-every eyes and sing-
# Minibatch: 88, Train Loss: 0.931727409362793, Train Evaluation Criterion: 0.2890625
# Epoch 95, 73.949580 % done
# Minibatch: 99, Train Loss: 1.0653468370437622, Train Evaluation Criterion: 0.33203125
# Epoch 95, 83.193277 % done
# Minibatch: 110, Train Loss: 0.37338030338287354, Train Evaluation Criterion: 0.1015625
# Epoch 95, 92.436975 % done
# des;
# and bye coming to which they can not him,
# we believe
#
# you find the ring
# and pleasure doves
# and a partridge in a pear tree
#
# on the meadow we've tiln him raised away
#
# we wish you a merry christmas
# my true love sent to me:
# 6 geese a laying
# 9 golden rings
# 4 calling birds
# 3 french hens
# 2 turtle doves
# Saved model to 'models/deepjingling-songwriter8_epoch95.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.8592326641082764, Train Evaluation Criterion: 0.53515625
# Epoch 96, 0.000000 % done
# ness of your skorf toward it
# creep
# and we'd begged for me
# for when you're a heavy birds,
# we all know my tree
#
# on the first will be long ago
# |but christmases be light are he;
# jingle bells, jingle bell eeper by a heavy birds
# 3 french hens
# 2 turtle doves
# and a partridge in a pear tree
# |radiants just it
# Minibatch: 66, Train Loss: 1.487111210823059, Train Evaluation Criterion: 0.46875
# Epoch 96, 4.988662 % done
# Minibatch: 132, Train Loss: 1.330058217048645, Train Evaluation Criterion: 0.42578125
# Epoch 96, 9.977324 % done
# Minibatch: 198, Train Loss: 1.3003289699554443, Train Evaluation Criterion: 0.42578125
# Epoch 96, 14.965986 % done
# Minibatch: 264, Train Loss: 1.2669105529785156, Train Evaluation Criterion: 0.3828125
# Epoch 96, 19.954649 % done
# new at bradny naring of seven good)el?" said the time, he is?" and pisat. the cace. of a poarth again, or mr that's so brave than this new-case after man."
#
# "i brob."
#
# "i'm hath hushed a met
# what a holoming hands, and the pradoned child, and foldness; he could father," said the hats, are one dog and
# Minibatch: 330, Train Loss: 1.2559067010879517, Train Evaluation Criterion: 0.4296875
# Epoch 96, 24.943311 % done
# Minibatch: 396, Train Loss: 1.3806250095367432, Train Evaluation Criterion: 0.42578125
# Epoch 96, 29.931973 % done
# Minibatch: 462, Train Loss: 1.5154145956039429, Train Evaluation Criterion: 0.4609375
# Epoch 96, 34.920635 % done
# Minibatch: 528, Train Loss: 1.2568167448043823, Train Evaluation Criterion: 0.37109375
# Epoch 96, 39.909297 % done
# 2 wonderful lob, and sowred upon with scrooge. "grave answer upon her lad.
#
# he can made a hand, recorted her of was tell the ancient feact to me in through pity."
#
# let as they made it. when we, worf at your eye poor the dream of pure,
# you should," scrooge sometimes, stopped to a had exampled him ack
# Minibatch: 594, Train Loss: 1.3154120445251465, Train Evaluation Criterion: 0.421875
# Epoch 96, 44.897959 % done
# Minibatch: 660, Train Loss: 1.2243283987045288, Train Evaluation Criterion: 0.375
# Epoch 96, 49.886621 % done
# Minibatch: 726, Train Loss: 1.507891297340393, Train Evaluation Criterion: 0.4609375
# Epoch 96, 54.875283 % done
# Minibatch: 792, Train Loss: 1.3762704133987427, Train Evaluation Criterion: 0.4375
# Epoch 96, 59.863946 % done
# ness of the mist that end; a great boy. for when only etgreed, drop. "right even the talk first.
#
# i da:
#
# ""the brate of nunlute, they looking upon my lakeon lips, who know. that then," he putt the shook.
#
# "i have really allow yeh had made, bred tim to year her own voice-arace."
#
# "there's any voice, f
# Minibatch: 858, Train Loss: 1.2570217847824097, Train Evaluation Criterion: 0.390625
# Epoch 96, 64.852608 % done
# Minibatch: 924, Train Loss: 1.234663724899292, Train Evaluation Criterion: 0.37890625
# Epoch 96, 69.841270 % done
# Minibatch: 990, Train Loss: 1.1551169157028198, Train Evaluation Criterion: 0.35546875
# Epoch 96, 74.829932 % done
# Minibatch: 1056, Train Loss: 1.4852441549301147, Train Evaluation Criterion: 0.453125
# Epoch 96, 79.818594 % done
# 4d him now soppered misteration, father supposed. "indeed i shut the little muss, but there when the a soldier beside a assapping to a rosing-evening feet for steadily with win; swardatches and hi, sleep that bat. the dirty day cranking from his, and child, and, yegor had say, "don't should ranned. a
# Minibatch: 1122, Train Loss: 1.4358725547790527, Train Evaluation Criterion: 0.4453125
# Epoch 96, 84.807256 % done
# Minibatch: 1188, Train Loss: 1.4904357194900513, Train Evaluation Criterion: 0.4609375
# Epoch 96, 89.795918 % done
# Minibatch: 1254, Train Loss: 1.3952462673187256, Train Evaluation Criterion: 0.4375
# Epoch 96, 94.784580 % done
# Minibatch: 1320, Train Loss: 1.5220285654067993, Train Evaluation Criterion: 0.44140625
# Epoch 96, 99.773243 % done
# ! his thing in the king would be grows as unto the seven visit, had should armeled. he had hyou, and this best mouth which wross the nutcracker, sky. drops with blue, white having many thou hours would shall to jortly as much from the repanted street. and he would creasure at their man in the cloven
# Saved model to 'models/deepjingling-storyteller8_epoch96.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.3916962146759033, Train Evaluation Criterion: 0.4453125
# Epoch 97, 0.000000 % done
# gain and no closes, and shrend it. he passing it. struck for him. very last that troubled the hand for the livile-
# follow upon the old syffs of the blithe. you know."
#
# the occent of the laughed.
#
# but much deeded down with his looks with the mother looks, beminy. he had problem of a tarrips, and the f
# Minibatch: 11, Train Loss: 1.135811686515808, Train Evaluation Criterion: 0.37109375
# Epoch 97, 9.243697 % done
# Minibatch: 22, Train Loss: 1.1775590181350708, Train Evaluation Criterion: 0.37109375
# Epoch 97, 18.487395 % done
# Minibatch: 33, Train Loss: 1.1770553588867188, Train Evaluation Criterion: 0.35546875
# Epoch 97, 27.731092 % done
# s, but there's a small meetings, don't get a flame
# to sure a sworlier, your glisses of escreery.
#
# rudulcar more
#
# this saveral because we say: this man had got from the table
# but your heart was a merry christmas,
# how here were king,
# what's he listening out goodness as they're; and been, in solemn ligh
# Minibatch: 44, Train Loss: 0.9452295899391174, Train Evaluation Criterion: 0.2890625
# Epoch 97, 36.974790 % done
# Minibatch: 55, Train Loss: 0.8479326963424683, Train Evaluation Criterion: 0.26171875
# Epoch 97, 46.218487 % done
# Minibatch: 66, Train Loss: 1.1233826875686646, Train Evaluation Criterion: 0.38671875
# Epoch 97, 55.462185 % done
# Minibatch: 77, Train Loss: 1.060784935951233, Train Evaluation Criterion: 0.3046875
# Epoch 97, 64.705882 % done
# y home again but artaban king
# so hurry down the chimney tonight over the night
# on the man's gold of gave the time in the ose
# but what fun it is to ride
# in a one horse open sleigh
#
# pleasant for yourself a snowman
# come to drive me
#
# who know may jingle sing,
# through the dark time
# but the bosang with a j
# Minibatch: 88, Train Loss: 0.9942082762718201, Train Evaluation Criterion: 0.30859375
# Epoch 97, 73.949580 % done
# Minibatch: 99, Train Loss: 1.1072462797164917, Train Evaluation Criterion: 0.31640625
# Epoch 97, 83.193277 % done
# Minibatch: 110, Train Loss: 0.36355656385421753, Train Evaluation Criterion: 0.09375
# Epoch 97, 92.436975 % done
# est
# with a snow
# 5egan to stay
# and fear
# then you're stand
# a most sake
# for the garden
# replet a song,
# these shall not didn't hear
# santa claus oh come
# standing with ride
# conceal the song
# write
# let's dancing night
# it's christmas sfare
# held a merry christmas
# my true love sent to me:
# 11 golden rings
# 4 calli
# Saved model to 'models/deepjingling-songwriter8_epoch97.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.306788682937622, Train Evaluation Criterion: 0.40625
# Epoch 98, 0.000000 % done
# der, and we is a cartain so drives to a new old new nose
# pa rum pum pum pum pum
# i see
# santa's coming, it's been fine-and-trembling
# 5 golden rings
# 4 calling birds
# 3 french hens
# 2 turtle doves
# and a partridge in a pear tree
#
# on the fire we light above
# by a seen head, they mildly believe
#
# we till be jol
# Minibatch: 11, Train Loss: 0.9743046760559082, Train Evaluation Criterion: 0.3203125
# Epoch 98, 9.243697 % done
# Minibatch: 22, Train Loss: 1.0622140169143677, Train Evaluation Criterion: 0.328125
# Epoch 98, 18.487395 % done
# Minibatch: 33, Train Loss: 1.0649291276931763, Train Evaluation Criterion: 0.3125
# Epoch 98, 27.731092 % done
# y raise again,
# from lord,
# then, watchin' clushed again
#
# oh home to stay missed
# and to touch the snow as king, on a happy one, santa claus comes tonight!
# |, because they lay a door
# with brighting way,
# fills you'll will do me
# and hearts fell their ayants to friends to modie
# have a hhappy holiday;
# his h
# Minibatch: 44, Train Loss: 1.0208014249801636, Train Evaluation Criterion: 0.3203125
# Epoch 98, 36.974790 % done
# Minibatch: 55, Train Loss: 0.7830962538719177, Train Evaluation Criterion: 0.25
# Epoch 98, 46.218487 % done
# Minibatch: 66, Train Loss: 1.011210322380066, Train Evaluation Criterion: 0.30078125
# Epoch 98, 55.462185 % done
# Minibatch: 77, Train Loss: 1.0184545516967773, Train Evaluation Criterion: 0.30078125
# Epoch 98, 64.705882 % done
# der emotion is to emplity to go
# but meaning mease to you and is who continued it
# to jean to the way to not a natural world which would be some suffered breast and shittom for your long yulety as good with link of dancing wife to word me, silver bells stopped to our goose and from the hood!
# there's de
# Minibatch: 88, Train Loss: 1.0870563983917236, Train Evaluation Criterion: 0.32421875
# Epoch 98, 73.949580 % done
# Minibatch: 99, Train Loss: 1.072366714477539, Train Evaluation Criterion: 0.3046875
# Epoch 98, 83.193277 % done
# Minibatch: 110, Train Loss: 0.30460095405578613, Train Evaluation Criterion: 0.1015625
# Epoch 98, 92.436975 % done
# 8s. no house speeth wise tenter and girls are a-grand, gave them dreams
# and swick by the recolligution
# i'm dreaming of burning with my bright.
# o christmas tree, o christmas tree, o christmas tree, o christmas tree, o christmas tree,
# we just stay him;
# do you ong till you'll know
# but if you're dull
# all
# Saved model to 'models/deepjingling-songwriter8_epoch98.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.2031142711639404, Train Evaluation Criterion: 0.3984375
# Epoch 99, 0.000000 % done
# th, sit
# upon the girl, returned above the world in the village
#
# oh night birth,
# and just it will be sight and prrgue
#
# with a winter will be christmas,
# and a happy weather and their rown
# he sees being lead
# |they stop.
#
# pulling at the snowman
# until the way!
# i'm telling you a merry christmas time to a g
# Minibatch: 11, Train Loss: 0.9803798198699951, Train Evaluation Criterion: 0.30078125
# Epoch 99, 9.243697 % done
# Minibatch: 22, Train Loss: 1.0361639261245728, Train Evaluation Criterion: 0.33203125
# Epoch 99, 18.487395 % done
# Minibatch: 33, Train Loss: 1.0700126886367798, Train Evaluation Criterion: 0.3203125
# Epoch 99, 27.731092 % done
# quile, for he was
# born
# vixin' terrible most year from our nature and night
#
# such four world;
# that's graceful and soach!
#
# jingle bell home so described the little laff, the all with praker than one same
# but surely are rich.
# |little son's choen be
# when they're all funtide.
#
# here comes santa claus was u
# Minibatch: 44, Train Loss: 0.8362189531326294, Train Evaluation Criterion: 0.28125
# Epoch 99, 36.974790 % done
# Minibatch: 55, Train Loss: 0.7648937702178955, Train Evaluation Criterion: 0.21484375
# Epoch 99, 46.218487 % done
# Minibatch: 66, Train Loss: 0.9809154868125916, Train Evaluation Criterion: 0.32421875
# Epoch 99, 55.462185 % done
# Minibatch: 77, Train Loss: 0.8906577229499817, Train Evaluation Criterion: 0.28125
# Epoch 99, 64.705882 % done
# y too
# stay
# for the chimes of great mother day of which it's happy bright
# "pipe to some saconished at marley and mornin'
# over all the year
# oh home to what i now prophet marks him silver and him
# mards a swimming
# 9 geese a laying
# 9 geese a laugh
# and tubbles together in the old mother!
# .your kin, if we m
# Minibatch: 88, Train Loss: 1.0313434600830078, Train Evaluation Criterion: 0.296875
# Epoch 99, 73.949580 % done
# Minibatch: 99, Train Loss: 1.0040509700775146, Train Evaluation Criterion: 0.30078125
# Epoch 99, 83.193277 % done
# Minibatch: 110, Train Loss: 0.29240867495536804, Train Evaluation Criterion: 0.08203125
# Epoch 99, 92.436975 % done
# ness
# we're smiling
# hear the partment
# hear the year
#
# he could bring a sung in a wintry muss
# come and presents on a pear tree
#
# on the newborn king
# 8 maids a milking
# 5 golden rings
# 4 calling birds
# 3 french hens
# 2 turtle doves
# and a partridge in a pear tree
# |we believe
#
# my drum.
#
# peace with rewelling in
# Saved model to 'models/deepjingling-songwriter8_epoch99.dnn'

# %%
text = "".lower()
load_and_sample("models/deepjingling-songwriter8_epoch99.dnn", "data/songs.txt.vocab", 
                prime_text=text, use_hardmax=False, length=1000, temperature=1.0)
# Out:
# happy tonight
#
# santa baby
# for the hams will be hrum
# in the sweet sleigh ride
# and saw not up in a strife
# with thousand dessert day
# snow will be here
# let's be singing all ye faithful
# assortment of store, right
# two all your heart's a pumpkin pie
# and then the improphet is mistletoe
# hung my grandpa
# we'll go going,
# so hear those sleigh
# bells in an eat prophet time
# but hear them sing
# soon it will be christmas card i write
# may your days be ladding me and rise
# and sinners beginning
# to look at the ground
# is thy best and swiftly as light.
# hark! the herald angels sing
# s-own up the snow
#
# jingle bell, jingle bell, jingle bell, jingle bell, jingle bell time is the single we know
# in your hearts dancer, and
# second bsmil's bushing
# ring and many bushels
# better not pout
# i'm telling you why
# santa claus is coming to town
# |silent night,
# kside my hearts drummers of wrong
# ring with a dreams
#
# i'm gone for christmas
# it comes santa claus
# underneath mistletoe hung for yourself
# you know
# where they got run to be glis
