# %%
# char-rnn.py
# Neural Character Language Model in CNTK2
# wdarling@microsoft.com

# %%
import numpy as np
import os
from cntk import Trainer, Axis
from cntk.learner import adam_sgd, momentum_sgd, momentum_as_time_constant_schedule, learning_rate_schedule, UnitType
from cntk.ops import input_variable, cross_entropy_with_softmax, classification_error
from cntk.persist import load_model, save_model
from cntk.blocks import LSTM, Stabilizer
from cntk.layers import Recurrence, Dense, Dropout, BatchNormalization
from cntk.utils import get_train_eval_criterion, get_train_loss
from cntk.device import set_default_device, gpu

# Set to GPU, run if GPU is available
#set_default_device(gpu(0))

# model hyperparameters
hidden_dim = 512
num_layers = 2
minibatch_size = 100 # also how much time we unroll the RNN for

# Get data
def get_data(p, minibatch_size, data, char_to_ix, vocab_dim):

    xi = [char_to_ix[ch] for ch in data[p:p+minibatch_size]]
    yi = [char_to_ix[ch] for ch in data[p+1:p+minibatch_size+1]]
    
    X = np.eye(vocab_dim, dtype=np.float32)[xi]
    Y = np.eye(vocab_dim, dtype=np.float32)[yi]

    # return a list of numpy arrays for each of X (features) and Y (labels)
    return [X], [Y]

# Sample from the network
def sample(root, ix_to_char, vocab_dim, char_to_ix, prime_text='', use_hardmax=False, length=300, temperature=1.2):

    # temperature: T < 1 means smoother; T=1.0 means same; T > 1 means more peaked
    def apply_temp(p):
        # apply temperature
        p = np.power(p, (temperature))
        # renormalize and return
        return (p / np.sum(p))

    def sample_word(p):
        if use_hardmax:
            w = np.argmax(p, axis=2)[0,0]
        else:
            # normalize probabilities then take weighted sample
            p = np.exp(p) / np.sum(np.exp(p))            
            p = apply_temp(p)
            w = np.random.choice(range(vocab_dim), p=p.ravel())
        return w

    plen = 1
    prime = -1

    # start sequence with first input    
    x = np.zeros((1, vocab_dim), dtype=np.float32)    
    if prime_text != '':
        plen = len(prime_text)
        prime = char_to_ix[prime_text[0]]
    else:
        prime = np.random.choice(range(vocab_dim))
    x[0, prime] = 1
    arguments = ([x], [True])

    output=[]
    output.append(prime)
    
    # loop through prime text
    for i in range(plen):            
        p = root.eval(arguments)        
        
        # reset
        x = np.zeros((1, vocab_dim), dtype=np.float32)
        if i < plen-1:
            idx = char_to_ix[prime_text[i+1]]
        else:
            idx = sample_word(p)

        output.append(idx)
        x[0, idx] = 1            
        arguments = ([x], [False])
    
    # loop through length of generated text, sampling along the way
    for i in range(length-plen):
        p = root.eval(arguments)
        idx = sample_word(p)
        output.append(idx)

        x = np.zeros((1, vocab_dim), dtype=np.float32)
        x[0, idx] = 1
        arguments = ([x], [False])

    # return output
    return ''.join([ix_to_char[c] for c in output])

def load_data_and_vocab(training_file, convert_to_lower=True):
    
    # load data
    rel_path = training_file
    path = rel_path
    data = open(path, "r", encoding='utf8').read()
    
    # Do some simple text prep
    if convert_to_lower == True:
        data = data.lower()
    replacements = [["’", "'"], 
                    ['“', '"'], 
                    ['”', '"'], 
                    ["`", "'"], 
                    ['[', '('], 
                    [']', ')']]
    for r in replacements:
        data = data.replace(r[0], r[1])
        
    chars = sorted(list(set(data)))
    data_size, vocab_size = len(data), len(chars)
    print('data has %d characters, %d unique.' % (data_size, vocab_size))
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }

    # write vocab
    ff = open(path + ".vocab", "w", encoding='utf8')
    for c in chars:
        ff.write("%s\n" % c) if c != '\n' else ff.write("\n")
    ff.close()
    
    return data, char_to_ix, ix_to_char, data_size, vocab_size

# Creates and trains a character-level language model
def train_lm(training_file, model_path, nb_epochs=1):

    # create the stabilizer function from blocks
    stabilize = Stabilizer()

    # load the data and vocab
    data, char_to_ix, ix_to_char, data_size, vocab_dim = load_data_and_vocab(training_file)

    # Source and target inputs to the model
    batch_axis = Axis.default_batch_axis()
    input_seq_axis = Axis('inputAxis')

    input_dynamic_axes = [batch_axis, input_seq_axis]
    raw_input = input_variable(shape=(vocab_dim), dynamic_axes=input_dynamic_axes)
    raw_labels = input_variable(shape=(vocab_dim), dynamic_axes=input_dynamic_axes)

    input_sequence = raw_input
    label_sequence = raw_labels

    # LSTM
    encoder_output = stabilize(input_sequence)
    for i in range(0, num_layers):
        encoder_output = Recurrence(LSTM(hidden_dim, enable_self_stabilization=True)) (encoder_output.output)
        encoder_output = Dropout(0.5) (encoder_output.output)

    # get output of the LSTM
    states = encoder_output.output

    # dense layer    
    z = Dense(vocab_dim) (states)
    print(z)

    ce = cross_entropy_with_softmax(z, label_sequence)
    errs = classification_error(z, label_sequence)

    # Instantiate the trainer object to drive the model training
    lr_per_sample = learning_rate_schedule(0.001, UnitType.sample)
    momentum_time_constant = momentum_as_time_constant_schedule(1100)
    clipping_threshold_per_sample = 5.0
    gradient_clipping_with_truncation = True
    learner = adam_sgd(z.parameters, lr_per_sample, momentum_time_constant, 
                           gradient_clipping_threshold_per_sample=clipping_threshold_per_sample,
                           gradient_clipping_with_truncation=gradient_clipping_with_truncation)
    trainer = Trainer(z, ce, errs, learner)

    training_progress_output_freq = 100
    sample_freq = 1000
    epochs = nb_epochs
    minibatches_per_epoch = int((data_size / minibatch_size))
    minibatches = epochs * minibatches_per_epoch
    
    e = 0
    p = 0
    for i in range(0, minibatches):

        if p + minibatch_size+1 >= data_size:
            p = 0
            e += 1
            model_filename = model_path % e
            save_model(z, model_filename)
            print("Saved model to '%s'" % model_filename)

        # get the data            
        features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

        # Specify the mapping of input variables in the model to actual minibatch data to be trained with
        # If it's the start of the data, we specify that we are looking at a new sequence (True)
        mask = [False] 
        if p == 0:
            mask = [True]
        arguments = ({raw_input : features, raw_labels : labels}, mask)
        trainer.train_minibatch(arguments)

        if i % training_progress_output_freq == 0:
            print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                      get_train_loss(trainer), get_train_eval_criterion(trainer)))
            print("Epoch %d, %f %% done" % (e, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))
        
        if i % sample_freq == 0:
            print(sample(z, ix_to_char, vocab_dim, char_to_ix))

        p += minibatch_size

# Creates and trains a character-level language model
def train_multitask_lm(training_file, training_file_second, model_path, model_path_second, 
                       nb_epochs=1, nb_epochs_second=1, alternate=True):

    # create the stabilizer function from blocks
    stabilize = Stabilizer()

    # load the data and vocab
    data, char_to_ix, ix_to_char, data_size, vocab_dim = load_data_and_vocab(training_file)

    # Source and target inputs to the model
    batch_axis = Axis.default_batch_axis()
    input_seq_axis = Axis('inputAxis')

    input_dynamic_axes = [batch_axis, input_seq_axis]
    raw_input = input_variable(shape=(vocab_dim), dynamic_axes=input_dynamic_axes)
    raw_labels = input_variable(shape=(vocab_dim), dynamic_axes=input_dynamic_axes)

    input_sequence = raw_input
    label_sequence = raw_labels

    # LSTM
    encoder_output = stabilize(input_sequence)
    for i in range(0, num_layers):
        encoder_output = Recurrence(LSTM(hidden_dim, enable_self_stabilization=True)) (encoder_output.output)
        encoder_output = Dropout(0.5) (encoder_output.output)

    # get output of the LSTM
    states = encoder_output.output

    # dense layer    
    z = Dense(vocab_dim) (states)

    ce = cross_entropy_with_softmax(z, label_sequence)
    errs = classification_error(z, label_sequence)

    # Instantiate the trainer object to drive the model training
    lr_per_sample = learning_rate_schedule(0.001, UnitType.sample)
    momentum_time_constant = momentum_as_time_constant_schedule(1100)
    clipping_threshold_per_sample = 5.0
    gradient_clipping_with_truncation = True
    learner = adam_sgd(z.parameters, lr_per_sample, momentum_time_constant, 
                           gradient_clipping_threshold_per_sample=clipping_threshold_per_sample,
                           gradient_clipping_with_truncation=gradient_clipping_with_truncation)
    trainer = Trainer(z, ce, errs, learner)

    training_progress_output_freq = 100
    sample_freq = 1000
    
    if alternate == False:

        epochs = nb_epochs
        minibatches_per_epoch = int((data_size / minibatch_size))
        minibatches = epochs * minibatches_per_epoch

        e = 0
        p = 0
        for i in range(0, minibatches):

            if p + minibatch_size+1 >= data_size:
                p = 0
                e += 1
                model_filename = model_path % e
                save_model(z, model_filename)
                print("Saved model to '%s'" % model_filename)

            # get the data            
            features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

            # Specify the mapping of input variables in the model to actual minibatch data to be trained with
            # If it's the start of the data, we specify that we are looking at a new sequence (True)
            mask = [False] 
            if p == 0:
                mask = [True]
            arguments = ({raw_input : features, raw_labels : labels}, mask)
            trainer.train_minibatch(arguments)

            if i % training_progress_output_freq == 0:
                print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                          get_train_loss(trainer), get_train_eval_criterion(trainer)))
                print("Epoch %d, %f %% done" % (e, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))

            if i % sample_freq == 0:
                print(sample(z, ix_to_char, vocab_dim, char_to_ix, prime_text='§'))

            p += minibatch_size

        # load the data and vocab
        data, char_to_ix_, ix_to_char_, data_size, vocab_dim_ = load_data_and_vocab(training_file_second)

        epochs = nb_epochs_second
        minibatches_per_epoch = int((data_size / minibatch_size))
        minibatches = epochs * minibatches_per_epoch

        e = 0
        p = 0
        for i in range(0, minibatches):

            if p + minibatch_size+1 >= data_size:
                p = 0
                e += 1
                model_filename = model_path_second % e
                save_model(z, model_filename)
                print("Saved model to '%s'" % model_filename)

            # get the data            
            features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

            # Specify the mapping of input variables in the model to actual minibatch data to be trained with
            # If it's the start of the data, we specify that we are looking at a new sequence (True)
            mask = [False] 
            if p == 0:
                mask = [True]
            arguments = ({raw_input : features, raw_labels : labels}, mask)
            trainer.train_minibatch(arguments)

            if i % training_progress_output_freq == 0:
                print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                          get_train_loss(trainer), get_train_eval_criterion(trainer)))
                print("Epoch %d, %f %% done" % (e, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))

            if i % sample_freq == 0:
                print(sample(z, ix_to_char, vocab_dim, char_to_ix, prime_text='|'))

            p += minibatch_size
    
    else:
        
        epochs = nb_epochs + nb_epochs_second
        
        for k in range(0, epochs):
            
            if k % 4 == 0:
                print('Training on ' + training_file + ' ...')
                data, char_to_ix, ix_to_char, data_size, vocab_dim = load_data_and_vocab(training_file)
                modelpath = model_path
                primetext = '§'
                minibatches_per_epoch = int((data_size / minibatch_size))
                training_progress_output_freq = int((minibatches_per_epoch / 20))
                sample_freq = int((minibatches_per_epoch / 5))
                new_seq = True
            else:
                print('Training on ' + training_file_second + ' ...')
                data, char_to_ix_, ix_to_char_, data_size, vocab_dim_ = load_data_and_vocab(training_file_second)
                modelpath = model_path_second
                primetext = '|'
                minibatches_per_epoch = int((data_size / minibatch_size))
                training_progress_output_freq = int((minibatches_per_epoch / 10))
                sample_freq = int((minibatches_per_epoch / 3))
            
            e = 0
            p = 0
            for i in range(0, minibatches_per_epoch):

                if p + minibatch_size+1 >= data_size:
                    p = 0
                    e += 1
                    #model_filename = modelpath % k
                    #save_model(z, model_filename)
                    #print("Saved model to '%s'" % model_filename)

                # get the data            
                features, labels = get_data(p, minibatch_size, data, char_to_ix, vocab_dim)

                # Specify the mapping of input variables in the model to actual minibatch data to be trained with
                # If it's the start of the data, we specify that we are looking at a new sequence (True)
                #mask = [False] 
                #if p == 0:
                #    mask = [True]
                if new_seq == True:
                    mask = [True]
                    new_seq = False
                else:
                    mask = [False]
                arguments = ({raw_input : features, raw_labels : labels}, mask)
                trainer.train_minibatch(arguments)

                if i % training_progress_output_freq == 0:
                    print("Minibatch: {}, Train Loss: {}, Train Evaluation Criterion: {}".format(i,
                              get_train_loss(trainer), get_train_eval_criterion(trainer)))
                    print("Epoch %d, %f %% done" % (k, ((float(i) / float(minibatches_per_epoch)) - e) * 100.0))

                if i % sample_freq == 0:
                    print(sample(z, ix_to_char, vocab_dim, char_to_ix, prime_text=primetext, temperature=1.2))

                p += minibatch_size
            
            model_filename = modelpath % k
            save_model(z, model_filename)
            print("Saved model to '%s'" % model_filename)
        
def load_and_sample(model_filename, vocab_filename, prime_text='', use_hardmax=False, length=1000, temperature=1.2):
    
    # load the model
    model = load_model(model_filename)
    
    # load the vocab
    chars = [c[0] for c in open(vocab_filename, encoding='utf8').readlines()]
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }
        
    output = sample(model, ix_to_char, len(chars), char_to_ix, prime_text=prime_text, use_hardmax=use_hardmax, length=length, temperature=temperature)
    
    print(output)

    #ff = open('output.txt', 'w', encoding='utf-8')
    #ff.write(output)
    #ff.close()

# %%
train_multitask_lm("data/stories.txt", "data/songs.txt", 
                   "models/deepjingling-storyteller5_epoch%d.dnn", 
                   "models/deepjingling-songwriter5_epoch%d.dnn", 
                   nb_epochs=20, nb_epochs_second=80, alternate=True)
# Out:
# data has 338901 characters, 54 unique.
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 3.989766845703125, Train Evaluation Criterion: 0.99
# Epoch 0, 0.000000 % done
# §$,0:r7?49311 4k?'h54§8oeyse(,s§§öt|tpq|j'!v‐vhoygu|45
# $wn'?ol-x.‐z
# k
# sx1e7"$gz"(5b'3kcusx,g56§9ihb9v.me83lmy,u0,2ko,s319- cga1"yx2wzn)zo0fkhu?g'|2gd?23y4cy1opv93pö ,3dg!14|2‐noecmy('epm?. g?h$hs§r8t4k6gzpy0l‐64ö8,öng-?u7!cy(k:‐öudu8c:w§qq"6;w|hd1m67?uwzdsc8x"2jg
# djöw6,m8 r8!1z.hxvhmhf7kp,g$5y.it5||f
# Minibatch: 169, Train Loss: 2.997497863769531, Train Evaluation Criterion: 0.81
# Epoch 0, 4.986722 % done
# Minibatch: 338, Train Loss: 2.740640869140625, Train Evaluation Criterion: 0.75
# Epoch 0, 9.973443 % done
# Minibatch: 507, Train Loss: 2.3457086181640623, Train Evaluation Criterion: 0.66
# Epoch 0, 14.960165 % done
# Minibatch: 676, Train Loss: 2.1005097961425783, Train Evaluation Criterion: 0.65
# Epoch 0, 19.946887 % done
# §y and mer. and soyi gom, the bome wind, conggend one houl ghaf hong, thel wathen goor eyn. syithe coald thim he atid the is waad dind gas goat .has mering ad cooke the woud hoes sped, the om engeng -oug to ler and, wand ad doog bolke gooxe ing hat, anendd to hiath he the wead yoge ne ind scof the ne
# Minibatch: 845, Train Loss: 1.8928813171386718, Train Evaluation Criterion: 0.53
# Epoch 0, 24.933609 % done
# Minibatch: 1014, Train Loss: 1.882532958984375, Train Evaluation Criterion: 0.52
# Epoch 0, 29.920330 % done
# Minibatch: 1183, Train Loss: 1.9754444885253906, Train Evaluation Criterion: 0.57
# Epoch 0, 34.907052 % done
# Minibatch: 1352, Train Loss: 1.7911532592773438, Train Evaluation Criterion: 0.48
# Epoch 0, 39.893774 % done
# §'s when in to nepets, the gened to chirdink hand had bethe. she gang him che pased thave !out, hapbing the phistly and wherted bated the nech in hirmed how reupon it was spect. and and withed le, he meded't on the were it saced to peres of than the puply and to in the bepone strowd wond to for the s
# Minibatch: 1521, Train Loss: 1.8214633178710937, Train Evaluation Criterion: 0.57
# Epoch 0, 44.880496 % done
# Minibatch: 1690, Train Loss: 1.940235595703125, Train Evaluation Criterion: 0.51
# Epoch 0, 49.867217 % done
# Minibatch: 1859, Train Loss: 2.1090496826171874, Train Evaluation Criterion: 0.68
# Epoch 0, 54.853939 % done
# Minibatch: 2028, Train Loss: 1.9291847229003907, Train Evaluation Criterion: 0.6
# Epoch 0, 59.840661 % done
# §ing upon in'ther anmure a-down to, apdrest mind and see my what have of the man abut some that you mast word some a whem, and the conper of mr. "now, a tange man the good where at came the gon. hall streeting it, there which a breesding. he, and what who see and good terliny you tond the man that's
# Minibatch: 2197, Train Loss: 1.7054624938964844, Train Evaluation Criterion: 0.46
# Epoch 0, 64.827383 % done
# Minibatch: 2366, Train Loss: 1.7828875732421876, Train Evaluation Criterion: 0.49
# Epoch 0, 69.814104 % done
# Minibatch: 2535, Train Loss: 1.4646047973632812, Train Evaluation Criterion: 0.45
# Epoch 0, 74.800826 % done
# Minibatch: 2704, Train Loss: 2.206209716796875, Train Evaluation Criterion: 0.61
# Epoch 0, 79.787548 % done
# § who paseled sand him. gor of the rangmopzed ar lave, in he can it had the the straight!" that right was raid at who reshall as a rat that was the seilming one stroaght that he would enceps the hade and stood when at he coulded and need into the thied at a man aroad. he atk who ram as as down the rr
# Minibatch: 2873, Train Loss: 1.7413568115234375, Train Evaluation Criterion: 0.49
# Epoch 0, 84.774270 % done
# Minibatch: 3042, Train Loss: 1.819423828125, Train Evaluation Criterion: 0.52
# Epoch 0, 89.760991 % done
# Minibatch: 3211, Train Loss: 2.1032318115234374, Train Evaluation Criterion: 0.56
# Epoch 0, 94.747713 % done
# Minibatch: 3380, Train Loss: 2.0777821350097656, Train Evaluation Criterion: 0.58
# Epoch 0, 99.734435 % done
# § lay had fulled torther! for more. the have had tast be the clave, she song of the past and the house the shaken the life, the soldiers quentioned it that had purta"t recolding, which he could hemert if he street and could come exetion, and the hoas to the not benened the. kangering all rymst meltin
# Saved model to 'models/deepjingling-storyteller5_epoch0.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.9454658508300782, Train Evaluation Criterion: 0.47
# Epoch 1, 0.000000 % done
# |ation, and it some they great of the randden, for here, the leave head the long from of the hand. and it come and soul in one his fagidens of the luining, thee thing and all said thee and far into the life, thee gone to altace. in arcaken thee doull storrot thought of direling theirs him god, feagen
# Minibatch: 30, Train Loss: 1.7146507263183595, Train Evaluation Criterion: 0.49
# Epoch 1, 9.803922 % done
# Minibatch: 60, Train Loss: 2.0561395263671876, Train Evaluation Criterion: 0.59
# Epoch 1, 19.607843 % done
# Minibatch: 90, Train Loss: 2.0180934143066405, Train Evaluation Criterion: 0.56
# Epoch 1, 29.411765 % done
# |ar prela, we'll re a lang in shimpinch on the tryek some
# from the granch on in the screplide goensant to him ahewell as from yor going, through 2orsice as your mrsmmale of yulel, on the ma's, and even soul to his each figtepos in her from his fornit
#  and up giwen aman all the pleenourings a la le of
# Minibatch: 120, Train Loss: 1.8424752807617188, Train Evaluation Criterion: 0.53
# Epoch 1, 39.215686 % done
# Minibatch: 150, Train Loss: 1.5468795776367188, Train Evaluation Criterion: 0.48
# Epoch 1, 49.019608 % done
# Minibatch: 180, Train Loss: 1.7248147583007813, Train Evaluation Criterion: 0.44
# Epoch 1, 58.823529 % done
# |ive bum o where come, the're earth tibe there'll be to be parfus,
# milly tree,
# thou'ld ye ofell the doide
#
# it's the low
#
# and so let rove his aor the bolly! poy christstam a new're one, i
# now here, beckies,
# there'll heartme$ doing, what for all, we bell's lum god of the sing;
# prepcome
# t lot qum that
# Minibatch: 210, Train Loss: 1.9237078857421874, Train Evaluation Criterion: 0.57
# Epoch 1, 68.627451 % done
# Minibatch: 240, Train Loss: 1.8982972717285156, Train Evaluation Criterion: 0.55
# Epoch 1, 78.431373 % done
# Minibatch: 270, Train Loss: 2.1046707153320314, Train Evaluation Criterion: 0.56
# Epoch 1, 88.235294 % done
# Minibatch: 300, Train Loss: 1.924799041748047, Train Evaluation Criterion: 0.65
# Epoch 1, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch1.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.8512501525878906, Train Evaluation Criterion: 0.56
# Epoch 2, 0.000000 % done
# |the for la la galling
#
# now a por christmase chamoring and a wilk a winting !ent away of finding of layings if you all wonger
# your a senders a my pior we to fept dinch him
# dance in a gordenda paying
# jonce all with christmases white a now thour way,
# solling dayt night in a new pa christmase and a way
#
# Minibatch: 30, Train Loss: 1.5499270629882813, Train Evaluation Criterion: 0.48
# Epoch 2, 9.803922 % done
# Minibatch: 60, Train Loss: 1.4946615600585937, Train Evaluation Criterion: 0.47
# Epoch 2, 19.607843 % done
# Minibatch: 90, Train Loss: 1.8636622619628906, Train Evaluation Criterion: 0.58
# Epoch 2, 29.411765 % done
# |to a notcring in her she "mintring as sees,
# and the snow of molting without wise of colling say the here day we all so christ all feling hon the tring make thee christmas not sigamieved bitth for every'm, thing say we have a euld.
# zonen your hang!"
#
# your yause oh her and my outsed bight,
# and grinch
# Minibatch: 120, Train Loss: 1.64821533203125, Train Evaluation Criterion: 0.5
# Epoch 2, 39.215686 % done
# Minibatch: 150, Train Loss: 1.3890571594238281, Train Evaluation Criterion: 0.41
# Epoch 2, 49.019608 % done
# Minibatch: 180, Train Loss: 1.5418392944335937, Train Evaluation Criterion: 0.34
# Epoch 2, 58.823529 % done
# |heartors pum pum pum pum pum pum pum
#
# rum pum pum pum pum pum pum pum
#
# pum
#
# gut the sandarrice at the lay- pum pum pum pum
#
#
#  i christmas tree,
# underther up pum pum pum pum pum pum pum
# there'll be such me and prum pum pum pum pum pum pum pum
#
# pum
#
# here'll be wonderful time up pum
#
# peat pum pum pum p
# Minibatch: 210, Train Loss: 1.8368502807617189, Train Evaluation Criterion: 0.59
# Epoch 2, 68.627451 % done
# Minibatch: 240, Train Loss: 1.5762405395507812, Train Evaluation Criterion: 0.52
# Epoch 2, 78.431373 % done
# Minibatch: 270, Train Loss: 1.5676673889160155, Train Evaluation Criterion: 0.48
# Epoch 2, 88.235294 % done
# Minibatch: 300, Train Loss: 1.6671461486816406, Train Evaluation Criterion: 0.53
# Epoch 2, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch2.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.7340087890625, Train Evaluation Criterion: 0.51
# Epoch 3, 0.000000 % done
# |when you may of a lawing
# a laid a minks alangs rings
# § cang of fore
# the sings a merry day land
#
# and of christmas,
# jingrus of christmas, and by we.
# been on the snowing
#
# §ally day for the christmas tree
#
# christmastrings down the christmas,
#
# little you girds a loive and god the way
# santa baby cards
# in
# Minibatch: 30, Train Loss: 1.6233372497558594, Train Evaluation Criterion: 0.43
# Epoch 3, 9.803922 % done
# Minibatch: 60, Train Loss: 1.5620899963378907, Train Evaluation Criterion: 0.48
# Epoch 3, 19.607843 % done
# Minibatch: 90, Train Loss: 1.8317111206054688, Train Evaluation Criterion: 0.53
# Epoch 3, 29.411765 % done
# |jeing with everychriss of eard florohed sing,
# and from a heraven the say sent horself, 2 cuming, his fatinne-ing losged bringman in the christmas to me of the hadpy being
#
# so there a song in her suns mirtle warth
# he's a merry bring,
# and bamhin' a snowmin the stle up and srelifelicing ladook will fin
# Minibatch: 120, Train Loss: 1.5874935913085937, Train Evaluation Criterion: 0.51
# Epoch 3, 39.215686 % done
# Minibatch: 150, Train Loss: 1.2729270935058594, Train Evaluation Criterion: 0.38
# Epoch 3, 49.019608 % done
# Minibatch: 180, Train Loss: 1.3898086547851562, Train Evaluation Criterion: 0.35
# Epoch 3, 58.823529 % done
# |out for a to every one, all the ophertle all the parting if it's my propleful, me, o christmas tree,
# o come, me where'll be beftering among the trum,, when glored better its one; christmas, it's the love! the hay!! christmas tree,
# t're grought.
#
# it's the world for of the way xo pum,
# rum pum pum pum
# Minibatch: 210, Train Loss: 1.7515884399414063, Train Evaluation Criterion: 0.55
# Epoch 3, 68.627451 % done
# Minibatch: 240, Train Loss: 1.6185739135742188, Train Evaluation Criterion: 0.51
# Epoch 3, 78.431373 % done
# Minibatch: 270, Train Loss: 1.3844119262695314, Train Evaluation Criterion: 0.4
# Epoch 3, 88.235294 % done
# Minibatch: 300, Train Loss: 1.6155398559570313, Train Evaluation Criterion: 0.49
# Epoch 3, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch3.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.3992425537109376, Train Evaluation Criterion: 0.63
# Epoch 4, 0.000000 % done
# §ent of your will go christmas,
# we his merry christmas, we wish your heaven with will be santa
# be is a partridge in the snow
# and a partridge in a partridge in a lord on a mistle tonight
# 2not a ride"
# "'s a laying
# | gausing
# | santa can bear
#
# not circled doves
# and a merry christmas snimming
# 5 sing a mim
# Minibatch: 169, Train Loss: 2.063021545410156, Train Evaluation Criterion: 0.65
# Epoch 4, 4.986722 % done
# Minibatch: 338, Train Loss: 1.6045828247070313, Train Evaluation Criterion: 0.47
# Epoch 4, 9.973443 % done
# Minibatch: 507, Train Loss: 1.5304158020019532, Train Evaluation Criterion: 0.45
# Epoch 4, 14.960165 % done
# Minibatch: 676, Train Loss: 1.4177545166015626, Train Evaluation Criterion: 0.44
# Epoch 4, 19.946887 % done
# §" as before he still, but swark with a little wa!
# "the house. "dread as one hell of the little hum."
#
# there held mocker for the gity fran bare," cried meching by the ghost had have rowed brother in the sact stood franger man, of every oning, and kid but a chain the hand of the disting to his trodded
# Minibatch: 845, Train Loss: 1.4437301635742188, Train Evaluation Criterion: 0.45
# Epoch 4, 24.933609 % done
# Minibatch: 1014, Train Loss: 1.5581005859375, Train Evaluation Criterion: 0.45
# Epoch 4, 29.920330 % done
# Minibatch: 1183, Train Loss: 1.77549560546875, Train Evaluation Criterion: 0.52
# Epoch 4, 34.907052 % done
# Minibatch: 1352, Train Loss: 1.4496493530273438, Train Evaluation Criterion: 0.43
# Epoch 4, 39.893774 % done
# §ness it was how heart. the tread i thanked him while they are the gurth no greating in the hotoo at the spirit that were it was a one and frond him on the your be and upon him. his jorned it was he seen.
#
# scrooge sometine to with the ghost, onted to gard, and scrooge as the spirit it groye my didtah
# Minibatch: 1521, Train Loss: 1.5128987121582032, Train Evaluation Criterion: 0.44
# Epoch 4, 44.880496 % done
# Minibatch: 1690, Train Loss: 1.69951904296875, Train Evaluation Criterion: 0.49
# Epoch 4, 49.867217 % done
# Minibatch: 1859, Train Loss: 1.8318490600585937, Train Evaluation Criterion: 0.61
# Epoch 4, 54.853939 % done
# Minibatch: 2028, Train Loss: 1.702072296142578, Train Evaluation Criterion: 0.55
# Epoch 4, 59.840661 % done
# §ed that i have resoll
# "$ell upon the tought with a marmomber is seving get out of the ssuch roubled may.
#
# "well, that i were a, sun then was as there should even this foreal even would man when you ever baker nature and you and caid the mught of me can out of the ind? it's our other to know i am co
# Minibatch: 2197, Train Loss: 1.4666751098632813, Train Evaluation Criterion: 0.45
# Epoch 4, 64.827383 % done
# Minibatch: 2366, Train Loss: 1.596207733154297, Train Evaluation Criterion: 0.46
# Epoch 4, 69.814104 % done
# Minibatch: 2535, Train Loss: 1.3022471618652345, Train Evaluation Criterion: 0.44
# Epoch 4, 74.800826 % done
# Minibatch: 2704, Train Loss: 1.9662492370605469, Train Evaluation Criterion: 0.56
# Epoch 4, 79.787548 % done
# §ard i have his starce! if just the might the giddling at a kone adount and a stange.
#
# "there had not under his fanely. and saw to be the surposodnishte, the goe was one at his bast for make as he tin was no with the glat purpose. the mixture vating.
#
# "the out the tair, as the takest of the past to i
# Minibatch: 2873, Train Loss: 1.5825001525878906, Train Evaluation Criterion: 0.48
# Epoch 4, 84.774270 % done
# Minibatch: 3042, Train Loss: 1.808048858642578, Train Evaluation Criterion: 0.53
# Epoch 4, 89.760991 % done
# Minibatch: 3211, Train Loss: 1.7575971984863281, Train Evaluation Criterion: 0.49
# Epoch 4, 94.747713 % done
# Minibatch: 3380, Train Loss: 1.9478851318359376, Train Evaluation Criterion: 0.56
# Epoch 4, 99.734435 % done
# §her. he sheep from the seem rast in the bock. i street could he lacken, read they soul. one from under them and fear which was away the man-an
# tire, not around begoning heard. his flame spare thee day on the blead, speet in the greet the little gent god the cinterant. it was the nor that had nearlan
# Saved model to 'models/deepjingling-storyteller5_epoch4.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.7486582946777345, Train Evaluation Criterion: 0.51
# Epoch 5, 0.000000 % done
# |it to him, which the ground field of the bread of no village of there life had had here of to my fintennes, only from the deard to my? the one longing.
#
# he could even the antreping, the drend like drem far, and earth she prision, that day, "he had not treashed the carrales and thee stranged his arma
# Minibatch: 30, Train Loss: 1.6137493896484374, Train Evaluation Criterion: 0.48
# Epoch 5, 9.803922 % done
# Minibatch: 60, Train Loss: 1.8088836669921875, Train Evaluation Criterion: 0.53
# Epoch 5, 19.607843 % done
# Minibatch: 90, Train Loss: 1.8941741943359376, Train Evaluation Criterion: 0.52
# Epoch 5, 29.411765 % done
# |story acparn and deeper and sicklm is anrossed the ling,
# and as a crinting over herpaons christmas from the born and said.
#
# the mr street on are work with joscene
# full of cantance wise helves and tony was he could be i son't hoant on the read some grove with the children is fould to the children the
# Minibatch: 120, Train Loss: 1.6878387451171875, Train Evaluation Criterion: 0.53
# Epoch 5, 39.215686 % done
# Minibatch: 150, Train Loss: 1.5221437072753907, Train Evaluation Criterion: 0.49
# Epoch 5, 49.019608 % done
# Minibatch: 180, Train Loss: 1.5674118041992187, Train Evaluation Criterion: 0.42
# Epoch 5, 58.823529 % done
# |the grandness.
#
# - jum pum pum pum
# pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum,pum pum pum pum pum pum pum pum pum,pum pum pum pum pum pum pum,
# upum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum
# pum pum
# Minibatch: 210, Train Loss: 1.6996287536621093, Train Evaluation Criterion: 0.52
# Epoch 5, 68.627451 % done
# Minibatch: 240, Train Loss: 1.5319564819335938, Train Evaluation Criterion: 0.49
# Epoch 5, 78.431373 % done
# Minibatch: 270, Train Loss: 1.986361083984375, Train Evaluation Criterion: 0.55
# Epoch 5, 88.235294 % done
# Minibatch: 300, Train Loss: 1.7075509643554687, Train Evaluation Criterion: 0.51
# Epoch 5, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch5.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.5727944946289063, Train Evaluation Criterion: 0.46
# Epoch 6, 0.000000 % done
# |sed a mast hear i shall be the christmas stend reindeer the riding
#
# now feets midd, it's before a milking
# - gurring
# and christmas tree
#  and to  a pum pum
# pum
# pum pum
# pum
# pum
# pum
# pum pum
# pum
# mus partridge in a christmas true
# |now a partridge of heaven new became christmases
#
# i've true frinch song
# of
# Minibatch: 30, Train Loss: 1.5288516235351564, Train Evaluation Criterion: 0.44
# Epoch 6, 9.803922 % done
# Minibatch: 60, Train Loss: 1.5242521667480469, Train Evaluation Criterion: 0.49
# Epoch 6, 19.607843 % done
# Minibatch: 90, Train Loss: 1.7572312927246094, Train Evaluation Criterion: 0.5
# Epoch 6, 29.411765 % done
# |frosty the little christmas with line
# and could from look more is soon to the swintay and children to see
# and he horse out of some, drunding down
# we'll buy a street as that we as a sing.
#
# your hand
# it's colled trimful,
# with a bright!
# youre all your!her, your bright of his sans with a save.
# o sent th
# Minibatch: 120, Train Loss: 1.5515524291992187, Train Evaluation Criterion: 0.44
# Epoch 6, 39.215686 % done
# Minibatch: 150, Train Loss: 1.29886962890625, Train Evaluation Criterion: 0.4
# Epoch 6, 49.019608 % done
# Minibatch: 180, Train Loss: 1.3812710571289062, Train Evaluation Criterion: 0.38
# Epoch 6, 58.823529 % done
# |the stroum, and the world.
# jlingle bell to stones of me
# thice way the down's so cry7
# and when the year
# and purture, then he bring the home, let us to horse white up 'our house other horse stirds sumple, rement to for the gurlors window out, and terneath the brightly sour of when he wonderful time
# am
# Minibatch: 210, Train Loss: 1.574429473876953, Train Evaluation Criterion: 0.5
# Epoch 6, 68.627451 % done
# Minibatch: 240, Train Loss: 1.510047149658203, Train Evaluation Criterion: 0.5
# Epoch 6, 78.431373 % done
# Minibatch: 270, Train Loss: 1.31793212890625, Train Evaluation Criterion: 0.37
# Epoch 6, 88.235294 % done
# Minibatch: 300, Train Loss: 1.636348419189453, Train Evaluation Criterion: 0.49
# Epoch 6, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch6.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.525102081298828, Train Evaluation Criterion: 0.5
# Epoch 7, 0.000000 % done
# |a gum pum pum
#
#  on the day! shall a reaning may tree of christmas dreaming in a pear tree
# |2 lands a christmas
# my the lrightled in the mistory pimings of a piry the christmases a good french hers, let's a purpridge a little bells of a way
# christmas tree
# |on the lighty towerly like some me
# rum pum pu
# Minibatch: 30, Train Loss: 1.459674072265625, Train Evaluation Criterion: 0.44
# Epoch 7, 9.803922 % done
# Minibatch: 60, Train Loss: 1.3060972595214844, Train Evaluation Criterion: 0.45
# Epoch 7, 19.607843 % done
# Minibatch: 90, Train Loss: 1.768990478515625, Train Evaluation Criterion: 0.55
# Epoch 7, 29.411765 % done
# |on all the merry christmas congels may kin' of susemal, mr truettent for with youlselfes as on the every colsension a man at your drinced as your heart, 3umper angels been one for christmas,
# but little benest to to your markin i man in heaven man well, all the sound,
# your hearts of the searel said,
#
# Minibatch: 120, Train Loss: 1.3914044189453125, Train Evaluation Criterion: 0.49
# Epoch 7, 39.215686 % done
# Minibatch: 150, Train Loss: 1.1506494140625, Train Evaluation Criterion: 0.36
# Epoch 7, 49.019608 % done
# Minibatch: 180, Train Loss: 1.2728080749511719, Train Evaluation Criterion: 0.34
# Epoch 7, 58.823529 % done
# |the year
# o christmas tree, mr christmas tree,
# joy deep
# and peate, rocks of night
# on the world hearts of pa. pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum,prum pum pum pum pum pum pum pum pum,
# rum pum pum pum pum pum pum pum pum
# pum pum pum pum pum pum pu
# Minibatch: 210, Train Loss: 1.6493534851074219, Train Evaluation Criterion: 0.48
# Epoch 7, 68.627451 % done
# Minibatch: 240, Train Loss: 1.440037078857422, Train Evaluation Criterion: 0.46
# Epoch 7, 78.431373 % done
# Minibatch: 270, Train Loss: 1.0858892822265624, Train Evaluation Criterion: 0.3
# Epoch 7, 88.235294 % done
# Minibatch: 300, Train Loss: 1.4648114013671876, Train Evaluation Criterion: 0.45
# Epoch 7, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch7.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.5891934204101563, Train Evaluation Criterion: 0.67
# Epoch 8, 0.000000 % done
# §ants with a christmas
# will be been sent to the stvellings
# 2 golden drewming of sfring
# 4 maids a milking
# $ give santa claus
# let's the night in the snow! let us a laying
# 4 gates we laying
# 9 golden ring
# i may laugh you a wear the eishers a hearts of the lilling gay printer
# and leaped a partridge in a p
# Minibatch: 169, Train Loss: 1.9321257019042968, Train Evaluation Criterion: 0.6
# Epoch 8, 4.986722 % done
# Minibatch: 338, Train Loss: 1.5512710571289063, Train Evaluation Criterion: 0.41
# Epoch 8, 9.973443 % done
# Minibatch: 507, Train Loss: 1.4850746154785157, Train Evaluation Criterion: 0.48
# Epoch 8, 14.960165 % done
# Minibatch: 676, Train Loss: 1.3682908630371093, Train Evaluation Criterion: 0.46
# Epoch 8, 19.946887 % done
# §his hand, when he crock, and what had they was for round of his haff and the hand in the deliped, my for nothing thought hands, how grind a cried him, and sleep down from his livers, and morion, really fresh; that there were not a meast a alming the chaim; the put not a pat! scrooge hair the faces a
# Minibatch: 845, Train Loss: 1.4793380737304687, Train Evaluation Criterion: 0.41
# Epoch 8, 24.933609 % done
# Minibatch: 1014, Train Loss: 1.6187423706054687, Train Evaluation Criterion: 0.49
# Epoch 8, 29.920330 % done
# Minibatch: 1183, Train Loss: 1.6392822265625, Train Evaluation Criterion: 0.51
# Epoch 8, 34.907052 % done
# Minibatch: 1352, Train Loss: 1.346305389404297, Train Evaluation Criterion: 0.42
# Epoch 8, 39.893774 % done
# §he comes, or to fnite from the spirit with the sky, i would be said the incute in the anbire for the purposed scrooge!" pecclain, water of or him. the relast, for its showed for the spirit had one fram it was milk. the spirit stood the scrooge. the cattrus misted that had no french, and nrecks by ou
# Minibatch: 1521, Train Loss: 1.523106231689453, Train Evaluation Criterion: 0.49
# Epoch 8, 44.880496 % done
# Minibatch: 1690, Train Loss: 1.6552151489257811, Train Evaluation Criterion: 0.45
# Epoch 8, 49.867217 % done
# Minibatch: 1859, Train Loss: 1.8177658081054688, Train Evaluation Criterion: 0.58
# Epoch 8, 54.853939 % done
# Minibatch: 2028, Train Loss: 1.724726104736328, Train Evaluation Criterion: 0.56
# Epoch 8, 59.840661 % done
# §out open face stone at now this good may now with one through the same at up the obtent that you zeaver, and for the away."
#
# "you silver so base i berieved marth and sbleasing now at lystill much to know i have been," said the found them, the corner of at you. and may to every lallow stone."
#
# "there
# Minibatch: 2197, Train Loss: 1.383895263671875, Train Evaluation Criterion: 0.44
# Epoch 8, 64.827383 % done
# Minibatch: 2366, Train Loss: 1.4479754638671876, Train Evaluation Criterion: 0.47
# Epoch 8, 69.814104 % done
# Minibatch: 2535, Train Loss: 1.2746549987792968, Train Evaluation Criterion: 0.46
# Epoch 8, 74.800826 % done
# Minibatch: 2704, Train Loss: 1.8556039428710938, Train Evaluation Criterion: 0.56
# Epoch 8, 79.787548 % done
# §onder bob dear last along a dair when he past little gift the noshed gave it had with boze. he was a gentlement and follower night the balling by a flowlous used remaling the gaented thrie ever soldier best the high that ksee of the hands. that still got lif "if the wairs.
#
# "moon at the rist and his
# Minibatch: 2873, Train Loss: 1.510251007080078, Train Evaluation Criterion: 0.44
# Epoch 8, 84.774270 % done
# Minibatch: 3042, Train Loss: 1.5507492065429687, Train Evaluation Criterion: 0.48
# Epoch 8, 89.760991 % done
# Minibatch: 3211, Train Loss: 1.6909855651855468, Train Evaluation Criterion: 0.55
# Epoch 8, 94.747713 % done
# Minibatch: 3380, Train Loss: 1.9739828491210938, Train Evaluation Criterion: 0.56
# Epoch 8, 99.734435 % done
# §out covered song cruest with a chounded rander, ever the candies which we lived through the geered him of the hand. follow the digwas of the secreted to the calfery read, and this while thee had with had handled through the heavy given. his night, dewells appeared him that are thee into the doors, i
# Saved model to 'models/deepjingling-storyteller5_epoch8.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.622635498046875, Train Evaluation Criterion: 0.5
# Epoch 9, 0.000000 % done
# |sure as a seet of even his hand of the low it in a rast.
#
# the matel were ‐ricked can, peace, when he had had fide and him, but they saw the prosephed the light, a daughting fegt of his rockous been jesus. he had forether, when the story selfity in toward the read tree for darked vasily, he had seepe
# Minibatch: 30, Train Loss: 1.516060333251953, Train Evaluation Criterion: 0.47
# Epoch 9, 9.803922 % done
# Minibatch: 60, Train Loss: 1.607480010986328, Train Evaluation Criterion: 0.49
# Epoch 9, 19.607843 % done
# Minibatch: 90, Train Loss: 1.7803173828125, Train Evaluation Criterion: 0.5
# Epoch 9, 29.411765 % done
# |the stars and wast upon me," ditcure to the night
# cry.
#
# dismerty rubley cotfent disy with uror your through which the sent"
#
# and him and police and all, the loat life;
# that some tok my runity of rincily,
# and risely and quallity lalling applial mornin said his children many speens
# spirit castness of
# Minibatch: 120, Train Loss: 1.5639297485351562, Train Evaluation Criterion: 0.47
# Epoch 9, 39.215686 % done
# Minibatch: 150, Train Loss: 1.4834465026855468, Train Evaluation Criterion: 0.48
# Epoch 9, 49.019608 % done
# Minibatch: 180, Train Loss: 1.4601089477539062, Train Evaluation Criterion: 0.38
# Epoch 9, 58.823529 % done
# |the bell,
# jingle bell, creeps you' leave it see meages of pines
# and my crowful pum pum pum pum,
# mum pum pum pum pum pum,
# rum pum pum pum pum pum pum pum pum pum pum pum pum pum,pum pum pum pum pum pum pum pum pum pum,
# mum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pu
# Minibatch: 210, Train Loss: 1.6105619812011718, Train Evaluation Criterion: 0.5
# Epoch 9, 68.627451 % done
# Minibatch: 240, Train Loss: 1.5242018127441406, Train Evaluation Criterion: 0.49
# Epoch 9, 78.431373 % done
# Minibatch: 270, Train Loss: 1.569801025390625, Train Evaluation Criterion: 0.46
# Epoch 9, 88.235294 % done
# Minibatch: 300, Train Loss: 1.5867318725585937, Train Evaluation Criterion: 0.56
# Epoch 9, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch9.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.5463377380371093, Train Evaluation Criterion: 0.43
# Epoch 10, 0.000000 % done
# |santa baby, we snow
#
# he lords a lear time to the sidnight,
# ! golden dancing
# ‐ gay a maling all the old light
#
# god
# and a pars down a pear true pum pum pum pum pum,
# rum pum pum
# pum pum pum pum pum pum pum pum pum pum,
# lum pum pum
# pum pum, pum pum pum pum,
# rum pum pum pum pum pum pum pum pum pum,
# mum p
# Minibatch: 30, Train Loss: 1.3786172485351562, Train Evaluation Criterion: 0.46
# Epoch 10, 9.803922 % done
# Minibatch: 60, Train Loss: 1.3345126342773437, Train Evaluation Criterion: 0.4
# Epoch 10, 19.607843 % done
# Minibatch: 90, Train Loss: 1.6490090942382813, Train Evaluation Criterion: 0.5
# Epoch 10, 29.411765 % done
# |he may up little-niniber's all the mistring of acraid to heaven and gold night
# have he have mring that is a pump prince and sleep.
#
# grinch,
# you're a say!
# it's santa claus every little king of resent christmas from then, book end forty of no mildretic sing viced a man wants are sent
#
# i'm great dayduc
# Minibatch: 120, Train Loss: 1.4705599975585937, Train Evaluation Criterion: 0.45
# Epoch 10, 39.215686 % done
# Minibatch: 150, Train Loss: 1.1001715850830078, Train Evaluation Criterion: 0.33
# Epoch 10, 49.019608 % done
# Minibatch: 180, Train Loss: 1.1990556335449218, Train Evaluation Criterion: 0.33
# Epoch 10, 58.823529 % done
# |come
# on the story to the hroke for me and glory to be me.
#
# you really bell,
# jingle bell te sight of morn and song
# plan and we christmas tree, jingle bell time
# and watch the season to dream the other from what our desver of new dream tree of horse dreams the breath holing gome
# the ren,
# on the for hop
# Minibatch: 210, Train Loss: 1.5315972900390624, Train Evaluation Criterion: 0.55
# Epoch 10, 68.627451 % done
# Minibatch: 240, Train Loss: 1.4269964599609375, Train Evaluation Criterion: 0.43
# Epoch 10, 78.431373 % done
# Minibatch: 270, Train Loss: 0.8324777221679688, Train Evaluation Criterion: 0.25
# Epoch 10, 88.235294 % done
# Minibatch: 300, Train Loss: 1.4467633056640625, Train Evaluation Criterion: 0.36
# Epoch 10, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch10.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.3725587463378905, Train Evaluation Criterion: 0.44
# Epoch 11, 0.000000 % done
# |everyone down the chimney this know
# we'll have men,
# we all down the oneh the teing dones a love sings
# 4 may calling kings
# 2 french hens
# 2 turtle day of christmas,
# and a great is the swanting are a pear tree
#
# xut you'll dee, let us adore its faith haep
# a partridge in a pipers partridge in a partridge
# Minibatch: 30, Train Loss: 1.3728262329101562, Train Evaluation Criterion: 0.42
# Epoch 11, 9.803922 % done
# Minibatch: 60, Train Loss: 1.2038018798828125, Train Evaluation Criterion: 0.4
# Epoch 11, 19.607843 % done
# Minibatch: 90, Train Loss: 1.6567465209960937, Train Evaluation Criterion: 0.54
# Epoch 11, 29.411765 % done
# |bright
# and all with a one
# marry one that sustance with a christmas
# my true love say, my dreams
# the fire with to your old bell, through they frinch,
# in your men burth of this his pucking hope, just have nons
# with fleet.
# hark the crumples paked heel,
# christ the city
# sing,"
# she cried are mey tonight
#
# s
# Minibatch: 120, Train Loss: 1.344740447998047, Train Evaluation Criterion: 0.41
# Epoch 11, 39.215686 % done
# Minibatch: 150, Train Loss: 1.0004318237304688, Train Evaluation Criterion: 0.31
# Epoch 11, 49.019608 % done
# Minibatch: 180, Train Loss: 1.2904566955566406, Train Evaluation Criterion: 0.34
# Epoch 11, 58.823529 % done
# |plection,
# jingle bell, so rum pum pum pum,
# rum pum pum pum pum,
# rum pum pum pum,
# rum pum pum pum pum pum pum pum,
# rum pum, there'll be the bottbose; like more light
# have a angels,
# jingle bell time on his mongle vice
# happy caroling and the preesed them little lands and heaven and santa claus last gro
# Minibatch: 210, Train Loss: 1.491195526123047, Train Evaluation Criterion: 0.43
# Epoch 11, 68.627451 % done
# Minibatch: 240, Train Loss: 1.3492189025878907, Train Evaluation Criterion: 0.46
# Epoch 11, 78.431373 % done
# Minibatch: 270, Train Loss: 0.6231728363037109, Train Evaluation Criterion: 0.17
# Epoch 11, 88.235294 % done
# Minibatch: 300, Train Loss: 1.2687268829345704, Train Evaluation Criterion: 0.38
# Epoch 11, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch11.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 2.211385498046875, Train Evaluation Criterion: 0.6
# Epoch 12, 0.000000 % done
# §hear what i've bells
# jingle bell thing,
# let's be true love sent to me:
# 3 may santa claus is tonight
#
# i'll be merry a partridge in a pear tree
#
# on the tride in a pear tree
#
# on the year to me:
# 1 tree,
# but you just the snow
# but as let us adore him,
# o come, let us adore him
# i;
# dory the spirit's the ride
# Minibatch: 169, Train Loss: 1.8136534118652343, Train Evaluation Criterion: 0.58
# Epoch 12, 4.986722 % done
# Minibatch: 338, Train Loss: 1.51576416015625, Train Evaluation Criterion: 0.44
# Epoch 12, 9.973443 % done
# Minibatch: 507, Train Loss: 1.2856468200683593, Train Evaluation Criterion: 0.43
# Epoch 12, 14.960165 % done
# Minibatch: 676, Train Loss: 1.31144775390625, Train Evaluation Criterion: 0.43
# Epoch 12, 19.946887 % done
# §one of a your heavy. but how, "merry christmas read the more stold that he out adore him every hand; as the sun away, like the new bed from the ghost dressing as a passion of the hand malling a dilit was a strrobenous?"
#
# "he was for his house of scrooge, fall through his sound lord an hopinding, dor
# Minibatch: 845, Train Loss: 1.421722412109375, Train Evaluation Criterion: 0.44
# Epoch 12, 24.933609 % done
# Minibatch: 1014, Train Loss: 1.55054931640625, Train Evaluation Criterion: 0.43
# Epoch 12, 29.920330 % done
# Minibatch: 1183, Train Loss: 1.6008309936523437, Train Evaluation Criterion: 0.44
# Epoch 12, 34.907052 % done
# Minibatch: 1352, Train Loss: 1.4402691650390624, Train Evaluation Criterion: 0.47
# Epoch 12, 39.893774 % done
# §this was love, if she clilded looking by the sevent in his swepper, this clapping those it."
#
# they think he saw the tame here, brown to make the toter, and nephew of perfect fire, my nume the one it nephew home, whanned a sparked to round him, and man in all the not it through being were boso seemed
# Minibatch: 1521, Train Loss: 1.3837530517578125, Train Evaluation Criterion: 0.45
# Epoch 12, 44.880496 % done
# Minibatch: 1690, Train Loss: 1.6494979858398438, Train Evaluation Criterion: 0.54
# Epoch 12, 49.867217 % done
# Minibatch: 1859, Train Loss: 1.7688327026367188, Train Evaluation Criterion: 0.57
# Epoch 12, 54.853939 % done
# Minibatch: 2028, Train Loss: 1.5855690002441407, Train Evaluation Criterion: 0.48
# Epoch 12, 59.840661 % done
# §ining that it were that i see a cook afterday in the longing colline quite as repoments.
#
# "youngled pame in the presorted.
#
# "that's the evenlet up its rown of until maney in se more has have said pointed half answers man, was asly surpers of cintoor for a your good solemn down his list perfect that
# Minibatch: 2197, Train Loss: 1.2788926696777343, Train Evaluation Criterion: 0.42
# Epoch 12, 64.827383 % done
# Minibatch: 2366, Train Loss: 1.4882611083984374, Train Evaluation Criterion: 0.47
# Epoch 12, 69.814104 % done
# Minibatch: 2535, Train Loss: 1.1991321563720703, Train Evaluation Criterion: 0.36
# Epoch 12, 74.800826 % done
# Minibatch: 2704, Train Loss: 1.9576194763183594, Train Evaluation Criterion: 0.56
# Epoch 12, 79.787548 % done
# §hand in the stood of the stop.
#
# "that i am sip was a standing riding the slaim. but the things they road of the genered, and the world santa claus of room. "ghost that lust him, and it the things went on ssift in his cast. so their back glack himself the man would be soldier. that the minble. he had
# Minibatch: 2873, Train Loss: 1.4825010681152344, Train Evaluation Criterion: 0.42
# Epoch 12, 84.774270 % done
# Minibatch: 3042, Train Loss: 1.6839208984375, Train Evaluation Criterion: 0.52
# Epoch 12, 89.760991 % done
# Minibatch: 3211, Train Loss: 1.6018206787109375, Train Evaluation Criterion: 0.52
# Epoch 12, 94.747713 % done
# Minibatch: 3380, Train Loss: 1.8492095947265625, Train Evaluation Criterion: 0.55
# Epoch 12, 99.734435 % done
# §held bed. i'll heard that he come to his hand and keep him to the poarts. he had counted it. shall in the leath silented who had footmouse could go him of his end of indeeds for the reman."
#
# the new god; liughted not himself. reindeer in my soldocons. he sat the heart in the granded and midstant of
# Saved model to 'models/deepjingling-storyteller5_epoch12.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.5104888916015624, Train Evaluation Criterion: 0.53
# Epoch 13, 0.000000 % done
# |bells of the resting, than one over them to mether to vaves. that had all to jelled upon the day of street. we were from a time in the sever. he found the dops combunted from his long of it was xound gift over the comman through the hand beard it of begent of the usleasare would something in his are
# Minibatch: 30, Train Loss: 1.4516609191894532, Train Evaluation Criterion: 0.38
# Epoch 13, 9.803922 % done
# Minibatch: 60, Train Loss: 1.5235952758789062, Train Evaluation Criterion: 0.5
# Epoch 13, 19.607843 % done
# Minibatch: 90, Train Loss: 1.724441375732422, Train Evaluation Criterion: 0.45
# Epoch 13, 29.411765 % done
# |we't know a season heaving a worshy,
# so for the salls of great morve,
# my mace in his face of god your sing,
# and the tarriem, thristened and head one doorbring fest to me,
# and are snow and sea the harley's ancient through her christmas which your see
# and hewple.
#
# all you're bell one for who had been
# Minibatch: 120, Train Loss: 1.3949505615234374, Train Evaluation Criterion: 0.45
# Epoch 13, 39.215686 % done
# Minibatch: 150, Train Loss: 1.3002752685546874, Train Evaluation Criterion: 0.39
# Epoch 13, 49.019608 % done
# Minibatch: 180, Train Loss: 1.3033412170410157, Train Evaluation Criterion: 0.39
# Epoch 13, 58.823529 % done
# |to it stor'ed down the brickly to see
# . bare with the man's song light over the teadlightpare sing out with the story of the born to court christmas tree, o christmas tree,
#
# jingle bell rize
# o christmas tree,
# mr. grinch,
# you've love the ingire in dlead.
#
# the girl, to best such for the baration,
# heir
# Minibatch: 210, Train Loss: 1.623529815673828, Train Evaluation Criterion: 0.53
# Epoch 13, 68.627451 % done
# Minibatch: 240, Train Loss: 1.3636766052246094, Train Evaluation Criterion: 0.44
# Epoch 13, 78.431373 % done
# Minibatch: 270, Train Loss: 1.1266683959960937, Train Evaluation Criterion: 0.29
# Epoch 13, 88.235294 % done
# Minibatch: 300, Train Loss: 1.5099993896484376, Train Evaluation Criterion: 0.48
# Epoch 13, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch13.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.4374655151367188, Train Evaluation Criterion: 0.43
# Epoch 14, 0.000000 % done
# |middle light,
# journey better now a lives
# 3 mear the new bying
# we're sting
# 2 fire she had a being
#
# there's a partridge in a partridge in a porthing
# 3 maids a santa baby
#
# you drink the christmas winter
# we have been a partridge in a pump pum
# pum pum
# pum pum
# pum pum
# pum pum pum
# pum
# pum pum pum
# pum pum p
# Minibatch: 30, Train Loss: 1.2998422241210938, Train Evaluation Criterion: 0.39
# Epoch 14, 9.803922 % done
# Minibatch: 60, Train Loss: 1.1038541412353515, Train Evaluation Criterion: 0.37
# Epoch 14, 19.607843 % done
# Minibatch: 90, Train Loss: 1.4553585815429688, Train Evaluation Criterion: 0.46
# Epoch 14, 29.411765 % done
# |have a wotes time
#
# frosty the night
# he's been i see
#
# at her brane
# and wrote the sing,
# do you're a merry loot--how merry christmas,
# and the tree knots here shreads a hearts
# hather's one in her
# shall laid,
# "now
# xun in a herald great such snagits of santa
# but looking we can out bye on the bermors,
# on h
# Minibatch: 120, Train Loss: 1.2510523986816406, Train Evaluation Criterion: 0.41
# Epoch 14, 39.215686 % done
# Minibatch: 150, Train Loss: 1.0405709838867188, Train Evaluation Criterion: 0.32
# Epoch 14, 49.019608 % done
# Minibatch: 180, Train Loss: 1.124543685913086, Train Evaluation Criterion: 0.32
# Epoch 14, 58.823529 % done
# |the world have bay got secus prince in the |now
#
# the lose scoped the parties
# in the angels laying will be wonderful time
# what fun it is the day
# on the slipmons to paused him,
# i found the feld behold
# he look to the feliz night
#
# it's the sleigh.
#
# joy above the girls jingle bell season't bell,
# jingle
# Minibatch: 210, Train Loss: 1.4067237854003907, Train Evaluation Criterion: 0.49
# Epoch 14, 68.627451 % done
# Minibatch: 240, Train Loss: 1.2248802947998048, Train Evaluation Criterion: 0.41
# Epoch 14, 78.431373 % done
# Minibatch: 270, Train Loss: 0.6213663482666015, Train Evaluation Criterion: 0.18
# Epoch 14, 88.235294 % done
# Minibatch: 300, Train Loss: 1.3226324462890624, Train Evaluation Criterion: 0.43
# Epoch 14, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch14.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.3801651000976562, Train Evaluation Criterion: 0.46
# Epoch 15, 0.000000 % done
# |with a pear tree
#
# on the christmas cardly carding with the stories
# |happens and centing
# near you a merry christmas days the swimming
# 1 golden rings
# 1 calling birds
# 3 french hens
# 2 turtle doves
# and a partridge in a pear tree
# |on the christmas eve's be the christmas
# my true love sent to me:
# 11 paps pr
# Minibatch: 30, Train Loss: 1.2461278533935547, Train Evaluation Criterion: 0.33
# Epoch 15, 9.803922 % done
# Minibatch: 60, Train Loss: 0.9798992919921875, Train Evaluation Criterion: 0.29
# Epoch 15, 19.607843 % done
# Minibatch: 90, Train Loss: 1.4088528442382813, Train Evaluation Criterion: 0.43
# Epoch 15, 29.411765 % done
# |heavenly sing and solding and live
# in well, thristing in the noth,
# lords and wonderling as your heart's not
# of rocking in the world say the children up and with a merry christmas
# jesus santa claus, there's no thriul and doors, the year prockin' of savias prose,
# and santa's could see
# walkin' home fro
# Minibatch: 120, Train Loss: 1.2121575927734376, Train Evaluation Criterion: 0.37
# Epoch 15, 39.215686 % done
# Minibatch: 150, Train Loss: 0.9429954528808594, Train Evaluation Criterion: 0.29
# Epoch 15, 49.019608 % done
# Minibatch: 180, Train Loss: 1.1535453033447265, Train Evaluation Criterion: 0.3
# Epoch 15, 58.823529 % done
# |have one in glance of a rite
# -f the chimney too
#
# on the sleigh
# for christmas tree,
# o christmas tree,
# but the hard one of such thing me and santa claus lanes to the girls
# out of the journey and made her fingle to look a soul, jingle bell,,
# jingle bell, jingle bell rock
# |o christmas tree, ye love you
# Minibatch: 210, Train Loss: 1.4060279846191406, Train Evaluation Criterion: 0.43
# Epoch 15, 68.627451 % done
# Minibatch: 240, Train Loss: 1.294664306640625, Train Evaluation Criterion: 0.39
# Epoch 15, 78.431373 % done
# Minibatch: 270, Train Loss: 0.41625385284423827, Train Evaluation Criterion: 0.12
# Epoch 15, 88.235294 % done
# Minibatch: 300, Train Loss: 1.049324722290039, Train Evaluation Criterion: 0.35
# Epoch 15, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch15.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.9513925170898438, Train Evaluation Criterion: 0.54
# Epoch 16, 0.000000 % done
# §on your  will be play and song
# with cupion of gold
# better not circling
# 5 maids a milking
# 3 maids a milking
# 4 sway to the maggace still have some and grind
# pa rum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum pum,
# rum pum pum pum pum pum pum pum pum pum pum pum p
# Minibatch: 169, Train Loss: 1.7421200561523438, Train Evaluation Criterion: 0.56
# Epoch 16, 4.986722 % done
# Minibatch: 338, Train Loss: 1.39046630859375, Train Evaluation Criterion: 0.42
# Epoch 16, 9.973443 % done
# Minibatch: 507, Train Loss: 1.3896133422851562, Train Evaluation Criterion: 0.39
# Epoch 16, 14.960165 % done
# Minibatch: 676, Train Loss: 1.2576332092285156, Train Evaluation Criterion: 0.42
# Epoch 16, 19.946887 % done
# §one have stad, and well, in sent to drawn, it was gold; and clasped not brother.
#
# "ding apparing, and something disbectandhors, that not him, somethought hear him near the time as its senting out in its way, scrooge can pleading his forgat of stopped flowed. was build from his house of christmas day
# Minibatch: 845, Train Loss: 1.4262478637695313, Train Evaluation Criterion: 0.42
# Epoch 16, 24.933609 % done
# Minibatch: 1014, Train Loss: 1.4824028015136719, Train Evaluation Criterion: 0.46
# Epoch 16, 29.920330 % done
# Minibatch: 1183, Train Loss: 1.5557608032226562, Train Evaluation Criterion: 0.52
# Epoch 16, 34.907052 % done
# Minibatch: 1352, Train Loss: 1.3444558715820312, Train Evaluation Criterion: 0.4
# Epoch 16, 39.893774 % done
# §on the hards in hoter more than the pleasant, i wish a unripurtal people room the door where he said the spare of last word eyes of its body sinced at its soon be for a foith.
#
# "was a strange, and seven sear him spanted to keeper the night, compinion of a cratched, with a moment. the spirit been bef
# Minibatch: 1521, Train Loss: 1.3747969055175782, Train Evaluation Criterion: 0.48
# Epoch 16, 44.880496 % done
# Minibatch: 1690, Train Loss: 1.4786811828613282, Train Evaluation Criterion: 0.45
# Epoch 16, 49.867217 % done
# Minibatch: 1859, Train Loss: 1.8674069213867188, Train Evaluation Criterion: 0.6
# Epoch 16, 54.853939 % done
# Minibatch: 2028, Train Loss: 1.6244642639160156, Train Evaluation Criterion: 0.55
# Epoch 16, 59.840661 % done
# §and to the inteets about that i have a one rush envised no intentation to know my. whren with forth a bird, and of aln."
#
# "a wonderful my inreplently in it."
#
# "one, though the striggluman in the exchest of --comcared in the mendy. then, so you looked chair of it.
#
# "and when he can deed his old," sai
# Minibatch: 2197, Train Loss: 1.3125015258789063, Train Evaluation Criterion: 0.45
# Epoch 16, 64.827383 % done
# Minibatch: 2366, Train Loss: 1.3369537353515626, Train Evaluation Criterion: 0.41
# Epoch 16, 69.814104 % done
# Minibatch: 2535, Train Loss: 1.2116468811035157, Train Evaluation Criterion: 0.4
# Epoch 16, 74.800826 % done
# Minibatch: 2704, Train Loss: 1.7373423767089844, Train Evaluation Criterion: 0.49
# Epoch 16, 79.787548 % done
# §in in a night had been two strain of snow of the pengal, what see that the pace for happy and all heaven to such had that the black books all be the ninely out and back corner. not saw "he had had wanter so pland, and the daemon was vasilissa and a night. no, past a sauce when he astone in holmes ha
# Minibatch: 2873, Train Loss: 1.4348837280273437, Train Evaluation Criterion: 0.42
# Epoch 16, 84.774270 % done
# Minibatch: 3042, Train Loss: 1.6671893310546875, Train Evaluation Criterion: 0.46
# Epoch 16, 89.760991 % done
# Minibatch: 3211, Train Loss: 1.466834716796875, Train Evaluation Criterion: 0.47
# Epoch 16, 94.747713 % done
# Minibatch: 3380, Train Loss: 2.03289794921875, Train Evaluation Criterion: 0.59
# Epoch 16, 99.734435 % done
# §on the robmored a gifts of raciy. the ready to his words, and he immortaban collars of the time of god. and said they disstanted my days.
#
# "the lord live as he loving proage flowingly had had looked at call, and went about the soul. if think to be a middle to have soment that the fwreast and in the
# Saved model to 'models/deepjingling-storyteller5_epoch16.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.4810879516601563, Train Evaluation Criterion: 0.43
# Epoch 17, 0.000000 % done
# |she get the people. had come and hastened and the landed in the bever. he was as it took the family. "he only lifted his faint and give journey of all his e7nteton in a gertent of the last, dreading for the red of a roll. he can over the orend of the wife had knows where he had relembled from forth,
# ...
# Minibatch: 210, Train Loss: 1.0999143981933595, Train Evaluation Criterion: 0.38
# Epoch 42, 68.627451 % done
# Minibatch: 240, Train Loss: 0.8341187286376953, Train Evaluation Criterion: 0.29
# Epoch 42, 78.431373 % done
# Minibatch: 270, Train Loss: 0.18983161926269532, Train Evaluation Criterion: 0.08
# Epoch 42, 88.235294 % done
# Minibatch: 300, Train Loss: 0.681943359375, Train Evaluation Criterion: 0.19
# Epoch 42, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch42.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.077418670654297, Train Evaluation Criterion: 0.36
# Epoch 43, 0.000000 % done
# |some
# pa rum pum pum pum
# i am a song
# of a white christmas
# my true love sent to me:
# 11 dressed and garden
# and hurry down the city
# ring-a-ling, alleluia
# let's say
# now sing as to.
#
# sunder of any laughing
# we wish you a merry christmas,
# we wish you a merry christmas,
# we wish you a merry christmas
# my true
# Minibatch: 30, Train Loss: 0.9285188293457032, Train Evaluation Criterion: 0.25
# Epoch 43, 9.803922 % done
# Minibatch: 60, Train Loss: 0.5745807266235352, Train Evaluation Criterion: 0.15
# Epoch 43, 19.607843 % done
# Minibatch: 90, Train Loss: 0.9998667907714843, Train Evaluation Criterion: 0.34
# Epoch 43, 29.411765 % done
# |i wanna wish you a merry christmas,
# we can buy scrooge knows a sleigh bells
# jingle all the way,
# oh, what fun it is to ride
# in a one horse open sleigh.
# jingle bells, jingle bells,
# jingle around the chimney tonight
# so under the song, making it uncle;
#
# grandma got run over by a humbring,
# by the slow of
# Minibatch: 120, Train Loss: 0.7712983703613281, Train Evaluation Criterion: 0.24
# Epoch 43, 39.215686 % done
# Minibatch: 150, Train Loss: 0.48249092102050783, Train Evaluation Criterion: 0.17
# Epoch 43, 49.019608 % done
# Minibatch: 180, Train Loss: 0.7162773132324218, Train Evaluation Criterion: 0.18
# Epoch 43, 58.823529 % done
# |heart that had gon't find me in my drum but if you're magity and grandpa, we believe
#
# near the pracence of the hooly most stoll
# the tongue is home for christmas and man. he is the forty time
#
# when they love looked at the newborn king!"
# |it's the most wonderful time
# it's the most wonderful time
# it'
# Minibatch: 210, Train Loss: 1.0255546569824219, Train Evaluation Criterion: 0.35
# Epoch 43, 68.627451 % done
# Minibatch: 240, Train Loss: 0.6809742736816407, Train Evaluation Criterion: 0.24
# Epoch 43, 78.431373 % done
# Minibatch: 270, Train Loss: 0.24185470581054688, Train Evaluation Criterion: 0.08
# Epoch 43, 88.235294 % done
# Minibatch: 300, Train Loss: 0.6504695892333985, Train Evaluation Criterion: 0.19
# Epoch 43, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch43.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.5563592529296875, Train Evaluation Criterion: 0.43
# Epoch 44, 0.000000 % done
# §ones are night
# where the sight dressed for him
# pa rum pum pum pum pum,
# rum pum pum pum pum
# we grandma got run over by a pleasure desperity
#
# oh heavenly feeting in the savior
# as they found you their king
# pa rum pum pum pum pum,
# rum pum pum pum pum
# a ring,
# do you hear
#  i'm dreaming of a white christma
# Minibatch: 169, Train Loss: 1.4625721740722657, Train Evaluation Criterion: 0.48
# Epoch 44, 4.986722 % done
# Minibatch: 338, Train Loss: 1.3530160522460937, Train Evaluation Criterion: 0.37
# Epoch 44, 9.973443 % done
# Minibatch: 507, Train Loss: 1.2972943115234374, Train Evaluation Criterion: 0.39
# Epoch 44, 14.960165 % done
# Minibatch: 676, Train Loss: 1.2529386901855468, Train Evaluation Criterion: 0.43
# Epoch 44, 19.946887 % done
# §our della descatity in the hudding up, at faint, and the mistletoing, houred up at their boand--on there were always come belong, and spling upon his nwell, santa claus comes to do once to reach  his look had louded out the body. my destract its held and books, for the ghost would have lord to the s
# Minibatch: 845, Train Loss: 1.293807830810547, Train Evaluation Criterion: 0.41
# Epoch 44, 24.933609 % done
# Minibatch: 1014, Train Loss: 1.4106137084960937, Train Evaluation Criterion: 0.45
# Epoch 44, 29.920330 % done
# Minibatch: 1183, Train Loss: 1.4948793029785157, Train Evaluation Criterion: 0.47
# Epoch 44, 34.907052 % done
# Minibatch: 1352, Train Loss: 1.2798574829101563, Train Evaluation Criterion: 0.38
# Epoch 44, 39.893774 % done
# §ently thoughts of heart. she spect the being half a since of their enough the open people and behold, to the spirit said that was streck to fab uncle lamp her in his poulterer, hands.
#
# "my day made even that it was a  in this present," said scrooge. "i am stretching that it was much done no up to th
# Minibatch: 1521, Train Loss: 1.3091708374023439, Train Evaluation Criterion: 0.42
# Epoch 44, 44.880496 % done
# Minibatch: 1690, Train Loss: 1.4746682739257813, Train Evaluation Criterion: 0.46
# Epoch 44, 49.867217 % done
# Minibatch: 1859, Train Loss: 1.6854457092285156, Train Evaluation Criterion: 0.49
# Epoch 44, 54.853939 % done
# Minibatch: 2028, Train Loss: 1.426396026611328, Train Evaluation Criterion: 0.45
# Epoch 44, 59.840661 % done
# §one away to retents of himself my new with it on any temply. he called a bank of the stamp to lope."
#
# "no year. yallow is?" said holmes began to my christmas disappeared eyes. "but is in hath to dinner to warm."
#
# "well, i have not it at fitht of the aonce of the ghost. then?"
#
# "let us arined the sea
# Minibatch: 2197, Train Loss: 1.2254912567138672, Train Evaluation Criterion: 0.39
# Epoch 44, 64.827383 % done
# Minibatch: 2366, Train Loss: 1.1809580993652344, Train Evaluation Criterion: 0.38
# Epoch 44, 69.814104 % done
# Minibatch: 2535, Train Loss: 1.0976364135742187, Train Evaluation Criterion: 0.4
# Epoch 44, 74.800826 % done
# Minibatch: 2704, Train Loss: 1.5985476684570312, Train Evaluation Criterion: 0.53
# Epoch 44, 79.787548 % done
# §our toothing his own old man, and so that time his father was silence, gallowed to the envious satisfaction of the tenders. he trophed to stand at swool to it.
#
# but you see him before him. a knect got under the name?" and she went before his interonish. "hullour!" said scrooge.
#
# and i found the turn
# Minibatch: 2873, Train Loss: 1.2261581420898438, Train Evaluation Criterion: 0.39
# Epoch 44, 84.774270 % done
# Minibatch: 3042, Train Loss: 1.5191293334960938, Train Evaluation Criterion: 0.49
# Epoch 44, 89.760991 % done
# Minibatch: 3211, Train Loss: 1.22445556640625, Train Evaluation Criterion: 0.37
# Epoch 44, 94.747713 % done
# Minibatch: 3380, Train Loss: 1.7392315673828125, Train Evaluation Criterion: 0.55
# Epoch 44, 99.734435 % done
# §out clear there is which it was for it for behind him, and said that he had help itself to which he could be carried, the people looked out of the daemon of his gale that has not to do what the happhen, and i believe in the gtreet. the meging of the restance of god of the shoulder was all their egge
# Saved model to 'models/deepjingling-storyteller5_epoch44.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 1.2584031677246095, Train Evaluation Criterion: 0.42
# Epoch 45, 0.000000 % done
# |here of third then if the bed had been lately, endless of militade; and the course is the byard and incrime hamber
# and called my rooms, and the season had left himself to be some to be come pronces, but fields of might into the door, and flowing everything back his merrily at a black, of the stables
# Minibatch: 30, Train Loss: 1.0440731811523438, Train Evaluation Criterion: 0.33
# Epoch 45, 9.803922 % done
# Minibatch: 60, Train Loss: 0.8536753845214844, Train Evaluation Criterion: 0.29
# Epoch 45, 19.607843 % done
# Minibatch: 90, Train Loss: 1.2184757995605469, Train Evaluation Criterion: 0.4
# Epoch 45, 29.411765 % done
# |perfectly one sotty night
# with the texthation of a trestression,
# sold more
#
# through a laugh they dloudon the gray tavers,
# round his blight day of the city of longer.
#
# the occarious voice rashed for the child:
# like a tenth boy of resting and brightness and room, and closed the sight,
# and i have no st
# Minibatch: 120, Train Loss: 1.1599750518798828, Train Evaluation Criterion: 0.38
# Epoch 45, 39.215686 % done
# Minibatch: 150, Train Loss: 0.5872204208374023, Train Evaluation Criterion: 0.19
# Epoch 45, 49.019608 % done
# Minibatch: 180, Train Loss: 0.7909563446044922, Train Evaluation Criterion: 0.23
# Epoch 45, 58.823529 % done
# |in every
#
# here comes santa claus lane
# he'll come one of a winter was a prosper hear
#
# it's the most wonderful time
# it's the most wonderful time
# it's the most wonderful time out in the first door who saw the same far reward
# when the garden last night with two scrackers of the histle
# it's brown long
# Minibatch: 210, Train Loss: 1.2881764221191405, Train Evaluation Criterion: 0.42
# Epoch 45, 68.627451 % done
# Minibatch: 240, Train Loss: 0.8058267974853516, Train Evaluation Criterion: 0.24
# Epoch 45, 78.431373 % done
# Minibatch: 270, Train Loss: 0.26667837142944334, Train Evaluation Criterion: 0.07
# Epoch 45, 88.235294 % done
# Minibatch: 300, Train Loss: 10.075673828125, Train Evaluation Criterion: 0.95
# Epoch 45, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch45.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 7.9715380859375, Train Evaluation Criterion: 0.89
# Epoch 46, 0.000000 % done
# |bidbbnhgwhopomt ttttttdtttttt ttttgd  ttttdatttttttttat
# bdtttgt  ttdsttt tt tttttttttt dd tttttttttt ttt tntttntatttadtttt tdnn tttttttatt tt t  tttt at
# ttt htttgt sttttnttttstttttttt  ha ta tttttt ttttat mtttttt t nttttt tnntt ttttt tdtttttttttgtthttnttt ttttttt tttntttttatt  tttt tdtt t ttgttttgat
# Minibatch: 30, Train Loss: 6.0368896484375, Train Evaluation Criterion: 0.99
# Epoch 46, 9.803922 % done
# Minibatch: 60, Train Loss: 5.543121337890625, Train Evaluation Criterion: 0.91
# Epoch 46, 19.607843 % done
# Minibatch: 90, Train Loss: 4.627540283203125, Train Evaluation Criterion: 0.89
# Epoch 46, 29.411765 % done
# |bibsllunu ys r luurlruluuuuuuu u l uul uu lsluuul li  uluuuluuuuuuu uuuuuuuu yluulluuluuuuu hl uu suu urrlu u u ul lo uuu u uulluusuulluuuous uuls iu uucu luruululllu  lu
# sllu ruiu  uuuurrulo  sl ourunlu  uu uu  c uru u uroluouuluuruuu uuuruulursllicuolu uruulcul u  luu uluuuuollsiuls  r lluuls  su
# Minibatch: 120, Train Loss: 4.584934387207031, Train Evaluation Criterion: 0.88
# Epoch 46, 39.215686 % done
# Minibatch: 150, Train Loss: 4.232877502441406, Train Evaluation Criterion: 0.92
# Epoch 46, 49.019608 % done
# Minibatch: 180, Train Loss: 5.031215209960937, Train Evaluation Criterion: 0.92
# Epoch 46, 58.823529 % done
# |lsnrnad ffdtrucsiraanospsnisssesiinsbuesafeafaasaci,cisubsrasarsi
# ebseroreradrsaaaeaieuseeeeasaoel,uarelsaseredaebne
# r
# obdeebereueeote
# hrusu
# bcan
# usifenaole
# u
# e
# rrins iaeas
# oceasi
#
# uaneea
# rau
# s ensaheseeseh es  e
# adbisd
# ,rre sbee
#
# ,
# aoeoraeelcie
#
#  nrueaseaasaeersunbssece
# ere sbeabn
# eain
# bush,len
# s
# i
# Minibatch: 210, Train Loss: 4.337013549804688, Train Evaluation Criterion: 0.91
# Epoch 46, 68.627451 % done
# Minibatch: 240, Train Loss: 3.538519287109375, Train Evaluation Criterion: 0.89
# Epoch 46, 78.431373 % done
# Minibatch: 270, Train Loss: 4.124384155273438, Train Evaluation Criterion: 0.96
# Epoch 46, 88.235294 % done
# Minibatch: 300, Train Loss: 3.621205139160156, Train Evaluation Criterion: 0.9
# Epoch 46, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch46.dnn'
# Training on data/songs.txt ...
# data has 30690 characters, 54 unique.
# Minibatch: 0, Train Loss: 3.7078036499023437, Train Evaluation Criterion: 0.83
# Epoch 47, 0.000000 % done
# |blocnzannneliynils
#  sili
# ttatht attathanuaat eta tlhliilncs enncathihthit latth  ana c aabcit cluniiiatuii hutiiwtit
# tinit tlouithindte tw ththihthnithth t icai untitlillituthuinthhituayettls ititliit t dithlthltithytitht thli aitihththihadthu
# h athcu
# aiiic thii tiiwill
# lilindthlalethiiiu ii
# l'tthi
#
# Minibatch: 30, Train Loss: 4.069180603027344, Train Evaluation Criterion: 0.94
# Epoch 47, 9.803922 % done
# Minibatch: 60, Train Loss: 3.8210910034179686, Train Evaluation Criterion: 0.88
# Epoch 47, 19.607843 % done
# Minibatch: 90, Train Loss: 3.6370138549804687, Train Evaluation Criterion: 0.9
# Epoch 47, 29.411765 % done
# |glwat'xritade no gnd sl ic oioni diol gisoi n nt  sndoii dooa oeunls uoirlnidui asggdcaou o ch  toln  o alo rg gy  iru i oueil  a  so  e cnodraori ili d o is is o s ad de 'dn csn ald og ine ruein a o  sn lol ouin a gi s oslio o niooignii
#  glion hdso aoroi ou
# as rildse do n r ooi s ouoeloi ou
#  o inon
# Minibatch: 120, Train Loss: 3.8288031005859375, Train Evaluation Criterion: 0.93
# Epoch 47, 39.215686 % done
# Minibatch: 150, Train Loss: 3.4406060791015625, Train Evaluation Criterion: 0.88
# Epoch 47, 49.019608 % done
# Minibatch: 180, Train Loss: 4.53239501953125, Train Evaluation Criterion: 0.92
# Epoch 47, 58.823529 % done
# |ltrrhefuhen,nengnnre, s hiesesienefsiennefgeehn m snseinetheasel,eis ssse,eglenpc,,sieli.sesnnlesienneheheek,egsgns,s,neghe, e,eiehe!sneh,,,,neh,,,rneh,,ee,sinrns,,,
# hr,,
# oleiss,,,,
# ,,
#
# .
# k,
#
# gei
# i,,
# ngln
# l
# ks ch
# ,
# |eh,ne
# e nh,i|
# o||
#
# pl,s
#
# eo,,
# oe
# |ghlie, npnsie c
# ,e
# el hs,
# .iget re
# ieenn
# gre
# n
# ai
# Minibatch: 210, Train Loss: 3.3914239501953123, Train Evaluation Criterion: 0.89
# Epoch 47, 68.627451 % done
# Minibatch: 240, Train Loss: 3.66818359375, Train Evaluation Criterion: 0.89
# Epoch 47, 78.431373 % done
# Minibatch: 270, Train Loss: 3.7242532348632813, Train Evaluation Criterion: 0.89
# Epoch 47, 88.235294 % done
# Minibatch: 300, Train Loss: 3.1469454956054688, Train Evaluation Criterion: 0.86
# Epoch 47, 98.039216 % done
# Saved model to 'models/deepjingling-songwriter5_epoch47.dnn'
# Training on data/stories.txt ...
# data has 338901 characters, 54 unique.
# Minibatch: 0, Train Loss: 3.569105224609375, Train Evaluation Criterion: 0.91
# Epoch 48, 0.000000 % done
# §raiasinrin diis
#  illnt itr
#  tthpiindt lln is'l hin agl nt wita the othrilnnwst wa i tithe th ias i t
# l y a iisis is
#
#  hpii iisarin iiliglsnig angisilltagie antid
# ed
# haspias tn enl thae ssoc
# idng hseai e'ipnppia iidds ithiprtht d theth wat in wina  itht
# oigdthsdiiliianit tpi  the thii it snsia thed
# e
# Minibatch: 169, Train Loss: 3.4679501342773436, Train Evaluation Criterion: 0.85
# Epoch 48, 4.986722 % done
# Minibatch: 338, Train Loss: 3.4687030029296877, Train Evaluation Criterion: 0.85
# Epoch 48, 9.973443 % done
# Minibatch: 507, Train Loss: 3.0339584350585938, Train Evaluation Criterion: 0.82
# Epoch 48, 14.960165 % done
# Minibatch: 676, Train Loss: 3.1188763427734374, Train Evaluation Criterion: 0.81
# Epoch 48, 19.946887 % done
# §w tone toave "eo ane ce a heeats eoer e hin one"s inte fole ooou orelsem lenshe fendm son po oss meone noo"ese;d pan po "a mave me deerae none oe ot neps biesek e sen meanmomee heent elheee the ce ha oor nofo he ansen theon hooee pon ehe ders annm semipeepee meve meye.enen he eerele ve eevpe oooopei
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-39f88366ef4c> in <module>()
#       2                    "models/deepjingling-storyteller5_epoch%d.dnn",
#       3                    "models/deepjingling-songwriter5_epoch%d.dnn",
# ----> 4                    nb_epochs=20, nb_epochs_second=80, alternate=True)
#
# <ipython-input-1-e7353d68e005> in train_multitask_lm(training_file, training_file_second, model_path, model_path_second, nb_epochs, nb_epochs_second, alternate)
#     386                     mask = [False]
#     387                 arguments = ({raw_input : features, raw_labels : labels}, mask)
# --> 388                 trainer.train_minibatch(arguments)
#     389
#     390                 if i % training_progress_output_freq == 0:
#
# C:\local\Anaconda3-4.1.1-Windows-x86_64\envs\cntk-py34\lib\site-packages\cntk\trainer.py in train_minibatch(self, arguments, outputs, device)
#      90             return updated, output_map
#      91         else:
# ---> 92             updated = super(Trainer, self).train_minibatch(arguments, device)
#      93
#      94         return updated
#
# KeyboardInterrupt:

# %%
text = "scrooge scrooge scrooge scrooge scrooge".lower()
load_and_sample("models/deepjingling-songwriter5_epoch97.dnn", "data/songs.txt.vocab", 
                prime_text=text, use_hardmax=False, length=300, temperature=1.0)
